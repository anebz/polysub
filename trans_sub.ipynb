# %%
from collections import OrderedDict

fname = '1x03c.srt'
subdata = OrderedDict()

'''
PART 1: PARSE THE DATA
'''
def process_lines(subdata: OrderedDict, chunk: list) -> OrderedDict:
    subdata[int(chunk[0])] = {
        'time': chunk[1],
        'text': ' '.join(chunk[2:])
    }
    return subdata

with open(fname, encoding='latin-1') as f:
    chunk = []
    lines = f.read().splitlines()

for line in lines:
    if line == '':
        if len(chunk) > 0:
            process_lines(subdata, chunk)
        chunk = []
    if line.isnumeric() or len(chunk) != 0:
        chunk.append(line)
if len(chunk) > 0:
    process_lines(subdata, chunk)

len(subdata)
subdata
# Out:
# OrderedDict([(2,
#               {'time': '00:01:04,560 --> 00:01:05,520',
#                'text': '              Ella dijo'}),
#              (3,
#               {'time': '00:01:04,560 --> 00:01:05,520',
#                'text': '              que me podia dar un regalo cuando yo vuelva.'}),
#              (4,
#               {'time': '00:01:04,560 --> 00:01:05,520',
#                'text': '              Y tambien dijo que hoy es jueves.'}),
#              (5,
#               {'time': '00:01:15,400 --> 00:01:16,360',
#                'text': '              Roja.'}),
#              (6,
#               {'time': '00:01:17,119 --> 00:01:18,560',
#                'text': '              Rojo.                -Roja.'}),
#              (7,
#               {'time': '00:01:20,000 --> 00:01:21,040',
#                'text': '              Roja.'}),
#              (8,
#               {'time': '00:01:27,160 --> 00:01:28,160',
#                'text': '              Roja.'}),
#              (9,
#               {'time': '00:03:35,879 --> 00:03:38,119',
#                'text': '             Hostia,  Â¿habÃ©is visto el campus virtual?'}),
#              (10,
#               {'time': '00:03:38,280 --> 00:03:40,400',
#                'text': '     Hoy la clase de Cultura        es en el aula 110.'}),
#              (11,
#               {'time': '00:03:41,920 --> 00:03:44,400',
#                'text': '      Pues vamos para allÃ¡,    que si no, no habrÃ¡ sitio...'}),
#              (12,
#               {'time': '00:03:44,560 --> 00:03:46,560',
#                'text': '        No, desayunamos,       nos relajamos y ya...'}),
#              (13,
#               {'time': '00:03:46,720 --> 00:03:49,439',
#                'text': '      Bueno, ya tenÃ\xada ganas  de sentarme con mis compaÃ±eros,'}),
#              (14,
#               {'time': '00:03:49,600 --> 00:03:51,560',
#                'text': '          que me meten     puÃ±aladas por la espalda.'}),
#              (15,
#               {'time': '00:03:51,720 --> 00:03:53,479',
#                'text': '       Â¿No estÃ¡s enfadado?          -Â¿Yo? Â¡QuÃ© va!'}),
#              (16,
#               {'time': '00:03:53,640 --> 00:03:55,000',
#                'text': '    El ejercicio es buenÃ\xadsimo.'}),
#              (17,
#               {'time': '00:03:55,160 --> 00:03:57,200',
#                'text': '             AdemÃ¡s, la BolaÃ±o es la bomba como profe.'}),
#              (18,
#               {'time': '00:03:57,360 --> 00:03:58,720',
#                'text': '    Pero a ver, explicÃ¡dmelo.'}),
#              (19,
#               {'time': '00:03:58,879 --> 00:04:01,600',
#                'text': '     O sea, Â¿ella os ha dicho   que yo llegarÃ\xada tarde a clase?'}),
#              (20,
#               {'time': '00:04:01,760 --> 00:04:04,200',
#                'text': '      No, no. Nos ha dicho   que si alguien llegaba tarde,'}),
#              (21,
#               {'time': '00:04:04,360 --> 00:04:06,280',
#                'text': '         nos preguntarÃ\xada       el color de la carpeta'}),
#              (22,
#               {'time': '00:04:06,439 --> 00:04:07,760',
#                'text': '      y que dijÃ©ramos rojo.               -SÃ\xad.'}),
#              (23,
#               {'time': '00:04:07,920 --> 00:04:09,640',
#                'text': 'Es que si lo piensas, es buenÃ\xadsimo.'}),
#              (24,
#               {'time': '00:04:11,119 --> 00:04:12,600',
#                'text': '   Pero tiene un puntito cruel.'}),
#              (25,
#               {'time': '00:04:13,119 --> 00:04:14,959',
#                'text': '       No lo dirÃ¡s por mÃ\xad.          -Bueno, pues...'}),
#              (26,
#               {'time': '00:04:15,119 --> 00:04:17,479',
#                'text': '        yo voy para allÃ¡,  que luego no habrÃ¡ sitio y no...'}),
#              (27,
#               {'time': '00:04:17,640 --> 00:04:18,680',
#                'text': '        Guarda para todos.'}),
#              (28,
#               {'time': '00:04:20,520 --> 00:04:22,920',
#                'text': '    Pero Â¿hay clase en la 110?              -No sÃ©.'}),
#              (29,
#               {'time': '00:04:28,840 --> 00:04:30,280',
#                'text': '    CÃ³mo os gusta jugar, Â¿eh?'}),
#              (30,
#               {'time': '00:04:30,439 --> 00:04:31,840',
#                'text': '         A la BolaÃ±o mÃ¡s.'}),
#              (31,
#               {'time': '00:04:51,320 --> 00:04:53,200',
#                'text': ' Y ahora, repetid todos conmigo.'}),
#              (32,
#               {'time': '00:05:02,800 --> 00:05:03,840',
#                'text': '           Una vez mÃ¡s.'}),
#              (33,
#               {'time': '00:05:12,560 --> 00:05:14,560',
#                'text': '         TÃ\xado, no me creo      que estÃ©s tan tranquilo.'}),
#              (34,
#               {'time': '00:05:14,720 --> 00:05:17,720',
#                'text': '     DespuÃ©s del "momentazo" que te ha hecho pasar la BolaÃ±o...'}),
#              (35,
#               {'time': '00:05:17,879 --> 00:05:20,800',
#                'text': 'Que sÃ\xad, "pesao". Â¿Me ves nervioso?       -No, tÃ\xado, pero primero'}),
#              (36,
#               {'time': '00:05:20,959 --> 00:05:22,959',
#                'text': '    no te corrige el trabajo,           ahora esto...'}),
#              (37,
#               {'time': '00:05:23,119 --> 00:05:25,959',
#                'text': '      Â¿QuÃ© le pasa contigo? -No sÃ©, los genios estÃ¡n "piraos".'}),
#              (38,
#               {'time': '00:05:26,119 --> 00:05:28,160',
#                'text': '  Pero le has seguido el juego.           Eso me jode.'}),
#              (39,
#               {'time': '00:05:28,320 --> 00:05:30,920',
#                'text': '     PodrÃ\xadas haberme avisado    de que iba a jugar conmigo.'}),
#              (40,
#               {'time': '00:05:31,080 --> 00:05:33,239',
#                'text': '      Primero vas de amigo,       pero despuÃ©s, Â¡toma!'}),
#              (41,
#               {'time': '00:05:33,400 --> 00:05:35,680',
#                'text': '          No te cabrees.    Esta noche tomamos una birra'}),
#              (42,
#               {'time': '00:05:36,479 --> 00:05:37,840',
#                'text': '       y asÃ\xad desconectamos.'}),
#              (43,
#               {'time': '00:05:38,520 --> 00:05:39,479',
#                'text': '              Vale.'}),
#              (44,
#               {'time': '00:05:39,640 --> 00:05:41,439',
#                'text': '             Â¿DÃ³nde?      -En el piso de Minerva.'}),
#              (45,
#               {'time': '00:05:42,200 --> 00:05:45,000',
#                'text': '    Acabo de hablar con ella.     Tiene una terraza guapÃ\xadsima.'}),
#              (46,
#               {'time': '00:05:45,160 --> 00:05:47,840',
#                'text': '   Ya os dirÃ©, estoy pendiente      de horarios del curro.'}),
#              (47,
#               {'time': '00:05:48,320 --> 00:05:51,200',
#                'text': '         TÃ\xado, Â¿quÃ© haces     en una mierda de parquin?'}),
#              (48,
#               {'time': '00:05:51,640 --> 00:05:54,520',
#                'text': 'Haz como Minerva, deja el trabajo.        -Venga, cÃ¡llate ya.'}),
#              (49,
#               {'time': '00:07:25,239 --> 00:07:26,720',
#                'text': '            Hola, Rai.               -Hola.'}),
#              (50,
#               {'time': '00:07:29,360 --> 00:07:30,360',
#                'text': '            Â¿QuÃ© tal?'}),
#              (51,
#               {'time': '00:07:31,080 --> 00:07:32,600',
#                'text': '     Â¿CÃ³mo va, Schopenhauer?'}),
#              (52,
#               {'time': '00:07:33,560 --> 00:07:34,840',
#                'text': '    AÃºn no hemos llegado a Ã©l.'}),
#              (53,
#               {'time': '00:07:35,959 --> 00:07:38,119',
#                'text': '           Yo tambiÃ©n    sÃ© un poquito de filosofÃ\xada.'}),
#              (54,
#               {'time': '00:07:38,280 --> 00:07:39,400',
#                'text': '         Ya me lo parece.'}),
#              (55,
#               {'time': '00:07:40,720 --> 00:07:42,080',
#                'text': '   Tu madre estÃ¡ en el jardÃ\xadn.'}),
#              (56,
#               {'time': '00:07:45,119 --> 00:07:46,400',
#                'text': '      DistraÃ\xadda, leyendo...'}),
#              (57,
#               {'time': '00:08:04,720 --> 00:08:06,800',
#                'text': '        Â¿DÃ³nde coÃ±o estÃ¡      el San Pedro de Verona?'}),
#              (58,
#               {'time': '00:08:07,720 --> 00:08:08,800',
#                'text': '              Â¡MamÃ¡!'}),
#              (59,
#               {'time': '00:08:10,360 --> 00:08:12,119',
#                'text': 'Â¿Es verdad que me robas el cuadro?'}),
#              (60,
#               {'time': '00:08:14,600 --> 00:08:16,520',
#                'text': '        Â¿Que te lo robo?         Â¿TÃº hablas de robo?'}),
#              (61,
#               {'time': '00:08:16,680 --> 00:08:18,320',
#                'text': 'Â¿TÃº que se lo robaste a los abuelos'}),
#              (62,
#               {'time': '00:08:18,479 --> 00:08:20,879',
#                'text': '           aprovechando que estaban en la casa de Calella?'}),
#              (63,
#               {'time': '00:08:21,040 --> 00:08:22,040',
#                'text': '       Yo salvÃ© el cuadro.'}),
#              (64,
#               {'time': '00:08:22,200 --> 00:08:24,080',
#                'text': '            Tu marido    hubiera sacado cuatro duros.'}),
#              (65,
#               {'time': '00:08:24,239 --> 00:08:25,439',
#                'text': '       Â¿Intentas justificar'}),
#              (66,
#               {'time': '00:08:25,600 --> 00:08:27,840',
#                'text': '      que entraras a robar       en casa de los abuelos?'}),
#              (67,
#               {'time': '00:08:28,760 --> 00:08:31,000',
#                'text': '      Â¿Nos calmamos un poco?        -Un italiano experto'}),
#              (68,
#               {'time': '00:08:31,160 --> 00:08:33,720',
#                'text': '      en pintura barroca irÃ¡  a la casa de subastas de Madrid.'}),
#              (69,
#               {'time': '00:08:33,879 --> 00:08:36,160',
#                'text': '   Julia quiere que certifique           si la pintura'}),
#              (70,
#               {'time': '00:08:36,320 --> 00:08:39,400',
#                'text': 'se puede atribuir a Claudio Coello.     No sÃ© si sabes quiÃ©n es.'}),
#              (71,
#               {'time': '00:08:39,640 --> 00:08:40,840',
#                'text': '        Mira, dos cositas.'}),
#              (72,
#               {'time': '00:08:41,080 --> 00:08:44,360',
#                'text': '   Primera: a Julia que le den.  SÃ\xad, que le den por culo a Julia.'}),
#              (73,
#               {'time': '00:08:44,520 --> 00:08:47,200',
#                'text': '     Y segunda: al italiano le envÃ\xadas una foto y a la mierda.'}),
#              (74,
#               {'time': '00:08:47,360 --> 00:08:49,479',
#                'text': '      Â¿Esta es la filosofÃ\xada       de tu nueva carrera?'}),
#              (75,
#               {'time': '00:08:49,640 --> 00:08:52,560',
#                'text': '    Â¡Necesitas un psicÃ³logo!   -Â¿PodÃ©is callaros, por favor?'}),
#              (76,
#               {'time': '00:08:52,720 --> 00:08:55,119',
#                'text': 'Victoria, es atribuible a Coello.          Ya te lo dije,'}),
#              (77,
#               {'time': '00:08:55,280 --> 00:08:58,080',
#                'text': ' se parece mucho al Santo Domingo       del museo de Budapest.'}),
#              (78,
#               {'time': '00:08:58,239 --> 00:08:59,920',
#                'text': ' QuizÃ¡ el italiano no haga falta.'}),
#              (79,
#               {'time': '00:09:07,800 --> 00:09:09,920',
#                'text': '        Â¿Ahora de repente      te interesa la pintura?'}),
#              (80,
#               {'time': '00:09:10,080 --> 00:09:11,920',
#                'text': '         Si ni te acercas       a la casa de subastas.'}),
#              (81,
#               {'time': '00:09:12,080 --> 00:09:13,600',
#                'text': '  Mira, que el cuadro se quede.'}),
#              (82,
#               {'time': '00:09:15,200 --> 00:09:18,320',
#                'text': 'Y maÃ±ana vienes a la inauguraciÃ³n      de la nueva exposiciÃ³n.'}),
#              (83,
#               {'time': '00:09:18,760 --> 00:09:21,800',
#                'text': 'AsÃ\xad demuestras un poco de interÃ©s      por el trabajo de mamÃ¡.'}),
#              (84,
#               {'time': '00:09:23,239 --> 00:09:24,959',
#                'text': ' Y no me gusta que le hables asÃ\xad.'}),
#              (85,
#               {'time': '00:09:25,920 --> 00:09:27,720',
#                'text': '       Vas a ir, Â¿eh, Rai?'}),
#              (86,
#               {'time': '00:09:32,600 --> 00:09:33,760',
#                'text': '            Voy a ir.'}),
#              (87,
#               {'time': '00:10:11,320 --> 00:10:12,600',
#                'text': '          Hasta maÃ±ana.              -AdiÃ³s.'}),
#              (88,
#               {'time': '00:10:27,239 --> 00:10:28,879',
#                'text': '         Que no, Gloria,'}),
#              (89,
#               {'time': '00:10:29,040 --> 00:10:31,560',
#                'text': '       que yo no entiendo  de mÃºsica clÃ¡sica y esas cosas.'}),
#              (90,
#               {'time': '00:10:32,040 --> 00:10:34,640',
#                'text': '             Ve tÃº.    -Estoy cansada de discutir.'}),
#              (91,
#               {'time': '00:10:36,520 --> 00:10:37,720',
#                'text': '          No pasa nada.'}),
#              (92,
#               {'time': '00:10:38,119 --> 00:10:39,560',
#                'text': '     Disfruta del concierto.'}),
#              (93,
#               {'time': '00:10:41,200 --> 00:10:42,439',
#                'text': '     Gloria, quÃ© guapa estÃ¡s.'}),
#              (94,
#               {'time': '00:10:42,600 --> 00:10:44,280',
#                'text': 'Gracias, al menos tÃº me lo dices.'}),
#              (95,
#               {'time': '00:10:44,840 --> 00:10:47,520',
#                'text': 'Â¿QuÃ© es lo primero que te he dicho?        Que estabas guapa.'}),
#              (96,
#               {'time': '00:10:47,680 --> 00:10:50,439',
#                'text': '  Tu padre no quiere acompaÃ±arme      a un concierto de piano.'}),
#              (97,
#               {'time': '00:10:56,119 --> 00:10:58,720',
#                'text': '      A ver si lo calmas tÃº,  que yo no puedo y llegarÃ© tarde.'}),
#              (98,
#               {'time': '00:10:58,879 --> 00:10:59,879',
#                'text': '        Yo tambiÃ©n me voy.'}),
#              (99,
#               {'time': '00:12:08,600 --> 00:12:10,479',
#                'text': ' Mirad a quiÃ©n me he encontrado.'}),
#              (100,
#               {'time': '00:12:12,680 --> 00:12:13,760',
#                'text': '            Muy bien.'}),
#              (101,
#               {'time': '00:12:13,920 --> 00:12:15,640',
#                'text': '  Bueno, quÃ© chulo es esto, Â¿no?'}),
#              (102,
#               {'time': '00:12:19,320 --> 00:12:20,760',
#                'text': '     Es un tÃ\xado de puta madre.'}),
#              (103,
#               {'time': '00:12:20,920 --> 00:12:22,959',
#                'text': ' Divertido, francÃ©s, pianista...'}),
#              (104,
#               {'time': '00:12:23,119 --> 00:12:24,400',
#                'text': '    Bueno, lo tiene todo, Â¿no?'}),
#              (105,
#               {'time': '00:12:25,439 --> 00:12:26,800',
#                'text': '     Â¿Y Rai con quiÃ©n habla?'}),
#              (106,
#               {'time': '00:12:27,400 --> 00:12:29,119',
#                'text': '  Con Amy. Tienes que conocerla.'}),
#              (107,
#               {'time': '00:12:29,280 --> 00:12:30,320',
#                'text': '         Es una "person".'}),
#              (108,
#               {'time': '00:12:32,680 --> 00:12:33,680',
#                'text': '              -Hola.'}),
#              (109,
#               {'time': '00:12:35,320 --> 00:12:37,080',
#                'text': "          Amy O'Connor,       soy de Eugene, OregÃ³n."}),
#              (110,
#               {'time': '00:12:37,520 --> 00:12:39,640',
#                'text': '        Cuidado que tiene   una pistola bajo la almohada.'}),
#              (111,
#               {'time': '00:12:39,800 --> 00:12:40,760',
#                'text': '         -Vale, escucha.'}),
#              (112,
#               {'time': '00:12:41,680 --> 00:12:42,680',
#                'text': '            No, claro.'}),
#              (113,
#               {'time': '00:12:42,879 --> 00:12:43,879',
#                'text': '             -Dije...'}),
#              (114,
#               {'time': '00:12:46,760 --> 00:12:47,840',
#                'text': '       Como una tradiciÃ³n.'}),
#              (115,
#               {'time': '00:12:48,000 --> 00:12:49,720',
#                'text': '          Una tradiciÃ³n,        como Halloween, Â¿no?'}),
#              (116,
#               {'time': '00:12:50,760 --> 00:12:53,600',
#                'text': '     -SÃ© que no es lo mismo, no lo entiendes porque no escuchas.'}),
#              (117,
#               {'time': '00:13:00,400 --> 00:13:01,640',
#                'text': '          Pol, escucha.'}),
#              (118,
#               {'time': '00:13:06,920 --> 00:13:08,320',
#                'text': '   No, un momento, un momento.'}),
#              (119,
#               {'time': '00:13:08,479 --> 00:13:10,800',
#                'text': '  No estÃ¡ mal, no, la pregunta.          Pensad un poco.'}),
#              (120,
#               {'time': '00:13:16,760 --> 00:13:19,000',
#                'text': '       Â¿Llamas a la policÃ\xada         y esperas? Pero...'}),
#              (121,
#               {'time': '00:13:20,560 --> 00:13:23,520',
#                'text': '    Lo siento por tu familia,     pero todos estÃ¡n muertos.'}),
#              (122,
#               {'time': '00:13:24,840 --> 00:13:26,800',
#                'text': '            Mi padre   tiene una escopeta de caza...'}),
#              (123,
#               {'time': '00:13:26,959 --> 00:13:30,280',
#                'text': 'A ver, si te entra peÃ±a a robar...  -A mÃ\xad no me robarÃ\xadan casi nada.'}),
#              (124,
#               {'time': '00:13:30,439 --> 00:13:32,400',
#                'text': '           Â¿La familia    merece que mates por ellos?'}),
#              (125,
#               {'time': '00:13:32,560 --> 00:13:35,119',
#                'text': '        Vale, tÃ\xados, basta.   Ya tengo el debate definitivo.'}),
#              (126,
#               {'time': '00:13:35,280 --> 00:13:37,520',
#                'text': '            Â¿CuÃ¡l es?  -Â¿Tenemos el culo que merecemos?'}),
#              (127,
#               {'time': '00:13:37,680 --> 00:13:38,920',
#                'text': '              Yo sÃ\xad.'}),
#              (128,
#               {'time': '00:13:39,080 --> 00:13:40,040',
#                'text': '              Yo sÃ\xad.'}),
#              (129,
#               {'time': '00:13:40,680 --> 00:13:41,720',
#                'text': '           Toca, toca.'}),
#              (130,
#               {'time': '00:13:42,160 --> 00:13:43,879',
#                'text': '           Toca, toca.             -Me encanta.'}),
#              (131,
#               {'time': '00:13:44,040 --> 00:13:45,479',
#                'text': '    Â¿A que tengo un buen culo?'}),
#              (132,
#               {'time': '00:13:45,640 --> 00:13:47,560',
#                'text': '       Es bonito. Â¿SÃ\xad o no?         -Hombre, pues sÃ\xad.'}),
#              (133,
#               {'time': '00:14:54,360 --> 00:14:55,360',
#                'text': '             -AdiÃ³s.'}),
#              (134,
#               {'time': '00:15:45,160 --> 00:15:47,239',
#                'text': '           Joder, Pol,     Â¿ya estÃ¡s bostezando, tÃ\xado?'}),
#              (135,
#               {'time': '00:15:48,680 --> 00:15:51,200',
#                'text': '    Para eso mejor no vengas,         quÃ©date en casa.'}),
#              (136,
#               {'time': '00:15:57,879 --> 00:16:00,080',
#                'text': '          El mayordomo  te espera en la puerta, Â¿o quÃ©?'}),
#              (137,
#               {'time': '00:16:00,720 --> 00:16:02,040',
#                'text': '        He venido solito.'}),
#              (138,
#               {'time': '00:16:02,479 --> 00:16:04,400',
#                'text': '   Â¿TÃº? Â¿Has pillado el metro?'}),
#              (139,
#               {'time': '00:16:05,520 --> 00:16:06,720',
#                'text': '       No te amargues, tÃ\xado.'}),
#              (140,
#               {'time': '00:16:06,879 --> 00:16:09,119',
#                'text': '            SÃ© feliz,  gÃ¡state el dinero en un chÃ³fer.'}),
#              (141,
#               {'time': '00:16:09,280 --> 00:16:11,959',
#                'text': '     Eres de los que piensan   que dinero es felicidad, Â¿no?'}),
#              (142,
#               {'time': '00:16:12,119 --> 00:16:13,119',
#                'text': '            No lo sÃ©.'}),
#              (143,
#               {'time': '00:16:14,360 --> 00:16:15,640',
#                'text': '         Â¿QuÃ© piensas tÃº?'}),
#              (144,
#               {'time': '00:16:17,479 --> 00:16:18,600',
#                'text': '          Pienso que...'}),
#              (145,
#               {'time': '00:16:19,760 --> 00:16:21,800',
#                'text': '             que soy  el Ãºnico estudiante de filosofÃ\xada'}),
#              (146,
#               {'time': '00:16:21,959 --> 00:16:24,439',
#                'text': '      al que no le preocupa    si la carrera tiene salida.'}),
#              (147,
#               {'time': '00:16:28,959 --> 00:16:30,320',
#                'text': '           Anda, sigue.'}),
#              (148,
#               {'time': '00:16:30,479 --> 00:16:31,600',
#                'text': '      Pues es muy sencillo.'}),
#              (149,
#               {'time': '00:16:32,280 --> 00:16:34,879',
#                'text': '           En mi vida hay cosas que no funcionan, pero...'}),
#              (150,
#               {'time': '00:16:35,600 --> 00:16:36,959',
#                'text': '       Â¡estoy tan relajado!'}),
#              (151,
#               {'time': '00:16:38,680 --> 00:16:40,479',
#                'text': '    No, hay mÃ¡s, aÃºn hay mÃ¡s.'}),
#              (152,
#               {'time': '00:16:41,400 --> 00:16:42,720',
#                'text': '     Cuando tengamos 40 aÃ±os,'}),
#              (153,
#               {'time': '00:16:43,320 --> 00:16:45,239',
#                'text': '       tÃº aparentarÃ¡s... 50'}),
#              (154,
#               {'time': '00:16:46,200 --> 00:16:47,439',
#                'text': '            y yo, 35.'}),
#              (155,
#               {'time': '00:16:55,720 --> 00:16:58,560',
#                'text': '         Â¿QuÃ© bombillas?      Â¿Las verdes o las rojas?'}),
#              (156,
#               {'time': '00:16:59,000 --> 00:17:01,360',
#                'text': '        Â¿Me ayudas, Pol?  Es que ahora mismo no sÃ©, no...'}),
#              (157,
#               {'time': '00:17:01,520 --> 00:17:02,879',
#                'text': '   Â¿TÃº quiÃ©n eras hace un aÃ±o?'}),
#              (158,
#               {'time': '00:17:04,040 --> 00:17:05,560',
#                'text': '        Â¿Eh? Â¿QuiÃ©n eras?'}),
#              (159,
#               {'time': '00:17:07,080 --> 00:17:09,200',
#                'text': '       Â¿Con quiÃ©n estabas?         Â¿QuiÃ©n te aguantaba?'}),
#              (160,
#               {'time': '00:17:09,360 --> 00:17:10,520',
#                'text': '     Â¿No tenÃ\xadas amigos pijos?'}),
#              (161,
#               {'time': '00:17:11,400 --> 00:17:14,040',
#                'text': '      SÃ\xad. SÃ\xad, me caducaron.'}),
#              (162,
#               {'time': '00:17:14,200 --> 00:17:16,520',
#                'text': '          Â¿Y quÃ© haces?  Â¿Buscas amigos entre los pobres?'}),
#              (163,
#               {'time': '00:17:16,680 --> 00:17:19,400',
#                'text': '   Â¿Por quÃ© te rebajas tanto?     Â¿No serÃ¡ que nos necesitas?'}),
#              (164,
#               {'time': '00:17:19,560 --> 00:17:20,560',
#                'text': '         Imposible, Â¿no?'}),
#              (165,
#               {'time': '00:17:21,119 --> 00:17:22,360',
#                'text': '      PodrÃ\xadas estar en casa,'}),
#              (166,
#               {'time': '00:17:22,520 --> 00:17:25,720',
#                'text': 'sin estrÃ©s, envejeciendo lentamente     y rodeado de la familia.'}),
#              (167,
#               {'time': '00:17:55,360 --> 00:17:56,320',
#                'text': '             Eh, Pol,'}),
#              (168,
#               {'time': '00:17:56,479 --> 00:17:57,800',
#                'text': '      Â¡no jodas que te vas!'}),
#              (169,
#               {'time': '00:17:57,959 --> 00:18:00,040',
#                'text': '               SÃ\xad.         -No, no. QuÃ©date.'}),
#              (170,
#               {'time': '00:18:00,640 --> 00:18:03,400',
#                'text': '    QuÃ©date, que le he robado    una cerveza a la americana.'}),
#              (171,
#               {'time': '00:18:04,320 --> 00:18:06,320',
#                'text': '       A ver si hay suerte        y no nos pega un tiro.'}),
#              (172,
#               {'time': '00:18:07,600 --> 00:18:09,000',
#                'text': '         Â¡Viva Misisipi!'}),
#              (173,
#               {'time': '00:18:12,160 --> 00:18:13,239',
#                'text': '               TÃ\xado,'}),
#              (174,
#               {'time': '00:18:14,000 --> 00:18:15,040',
#                'text': '          hoy en clase,'}),
#              (175,
#               {'time': '00:18:15,200 --> 00:18:17,959',
#                'text': '    cuando la BolaÃ±o ha hecho    el ejercicio de la carpeta,'}),
#              (176,
#               {'time': '00:18:19,439 --> 00:18:20,439',
#                'text': '        querÃ\xada abrazarte.'}),
#              (177,
#               {'time': '00:18:21,920 --> 00:18:22,920',
#                'text': '            Mira, asÃ\xad.'}),
#              (178,
#               {'time': '00:18:25,439 --> 00:18:26,920',
#                'text': '        Vale, vale. Vale.'}),
#              (179,
#               {'time': '00:18:30,200 --> 00:18:31,879',
#                'text': '            Oti... Va.'}),
#              (180,
#               {'time': '00:18:33,840 --> 00:18:36,040',
#                'text': 'Vale. Â¡Vale ya, vale ya, por favor!'}),
#              (181,
#               {'time': '00:18:36,479 --> 00:18:39,239',
#                'text': '        Me caes muy bien, pero no quiero nada contigo, Â¿vale?'}),
#              (182,
#               {'time': '00:18:41,680 --> 00:18:45,239',
#                'text': '        Es que me parece que la cerveza de Amy sube mucho.'}),
#              (183,
#               {'time': '00:18:45,920 --> 00:18:46,959',
#                'text': '          No pasa nada.'}),
#              (184,
#               {'time': '00:18:48,040 --> 00:18:50,040',
#                'text': '           Puedes subir    y que te dÃ© un poco el aire.'}),
#              (185,
#               {'time': '00:18:51,200 --> 00:18:53,720',
#                'text': 'No, no, mejor me voy a casa. Ten.'}),
#              (186,
#               {'time': '00:19:15,320 --> 00:19:18,200',
#                'text': '    -No es raro que te tiremos      los tejos, estÃ¡s caÃ±Ã³n.'}),
#              (187,
#               {'time': '00:19:19,239 --> 00:19:20,600',
#                'text': '     No entiendo el francÃ©s.'}),
#              (188,
#               {'time': '00:19:27,640 --> 00:19:28,720',
#                'text': '         Yo la entiendo.'}),
#              (189,
#               {'time': '00:19:42,439 --> 00:19:44,320',
#                'text': 'Los catalanes somos muy discretos.'}),
#              (190,
#               {'time': '00:20:22,000 --> 00:20:23,320',
#                'text': '       Â¿QuÃ© tal la fiesta?'}),
#              (191,
#               {'time': '00:20:24,040 --> 00:20:25,080',
#                'text': '              Bien.'}),
#              (192,
#               {'time': '00:20:27,560 --> 00:20:29,520',
#                'text': '      Ah, ha llamado Oriol.'}),
#              (193,
#               {'time': '00:20:30,720 --> 00:20:32,600',
#                'text': '       No le llames Oriol,         que es mi padre.'}),
#              (194,
#               {'time': '00:20:32,879 --> 00:20:34,879',
#                'text': '           QuerÃ\xada saber      si el domingo subiremos.'}),
#              (195,
#               {'time': '00:20:35,520 --> 00:20:36,920',
#                'text': '    Van a montar una barbacoa.'}),
#              (196,
#               {'time': '00:20:37,600 --> 00:20:39,600',
#                'text': '       Â¡Joder, quÃ© pesados!         No, no quiero ir.'}),
#              (197,
#               {'time': '00:20:40,360 --> 00:20:43,239',
#                'text': '   Es que mi padre me da palo  con sus monÃ³logos sobre fÃºtbol.'}),
#              (198,
#               {'time': '00:20:43,640 --> 00:20:44,640',
#                'text': '         Has bebido, Â¿eh?'}),
#              (199,
#               {'time': '00:20:46,360 --> 00:20:47,439',
#                'text': '           Un poquitÃ\xadn.'}),
#              (200,
#               {'time': '00:20:53,360 --> 00:20:55,600',
#                'text': '            Pues a mÃ\xad    me molarÃ\xada subir al pueblo.'}),
#              (201,
#               {'time': '00:20:55,760 --> 00:20:57,160',
#                'text': '       VerÃ\xadamos a la gente.'}),
#              (202,
#               {'time': '00:20:58,520 --> 00:21:00,800',
#                'text': ' Â¡Joder, quÃ© "pesao"! Pues ve tÃº.'}),
#              (203,
#               {'time': '00:21:00,959 --> 00:21:02,239',
#                'text': '        Yo me quedo aquÃ\xad.'}),
#              (204,
#               {'time': '00:21:03,560 --> 00:21:04,879',
#                'text': '     Es que he descubierto...'}),
#              (205,
#               {'time': '00:21:05,600 --> 00:21:07,160',
#                'text': '       que soy cosmopolita.'}),
#              (206,
#               {'time': '00:21:08,119 --> 00:21:09,800',
#                'text': '     Se confirma: has bebido.'}),
#              (207,
#               {'time': '00:21:11,560 --> 00:21:14,280',
#                'text': '      Venga, vamos a dormir.       -No, tÃº duermes aquÃ\xad,'}),
#              (208,
#               {'time': '00:21:14,439 --> 00:21:16,520',
#                'text': '         yo quiero dormir      a mis anchas en la cama.'}),
#              (209,
#               {'time': '00:21:16,760 --> 00:21:18,320',
#                'text': '     Y ponerme asÃ\xad, en cruz,'}),
#              (210,
#               {'time': '00:21:18,479 --> 00:21:20,560',
#                'text': '           y deshacerla     cuando a mÃ\xad me dÃ© la gana.'}),
#              (211,
#               {'time': '00:21:23,000 --> 00:21:24,600',
#                'text': '      Â¿Y vas a dejarme solo?'}),
#              (212,
#               {'time': '00:21:30,360 --> 00:21:32,520',
#                'text': '          Me pone tanto    que tengas algunas canas...'}),
#              (213,
#               {'time': '00:21:32,680 --> 00:21:34,000',
#                'text': '             Ah, Â¿sÃ\xad?'}),
#              (214,
#               {'time': '00:23:24,520 --> 00:23:26,320',
#                'text': 'Perdona, aquÃ\xad no puedes sentarte.'}),
#              (215,
#               {'time': '00:23:26,920 --> 00:23:28,959',
#                'text': '        Parece que muriÃ³       una seÃ±ora de 80 aÃ±os'}),
#              (216,
#               {'time': '00:23:29,119 --> 00:23:30,800',
#                'text': '   que venÃ\xada de oyente y no...'}),
#              (217,
#               {'time': '00:23:39,200 --> 00:23:41,400',
#                'text': '       Â¿Ya no quieres saber       quÃ© hacÃ\xada hace un aÃ±o?'}),
#              (218,
#               {'time': '00:23:43,200 --> 00:23:44,600',
#                'text': '           Hace un aÃ±o,'}),
#              (219,
#               {'time': '00:23:45,360 --> 00:23:47,560',
#                'text': '            me enterÃ© de que mi padre engaÃ±Ã³ a mi abuelo'}),
#              (220,
#               {'time': '00:23:47,720 --> 00:23:49,040',
#                'text': '     para robarle la empresa.'}),
#              (221,
#               {'time': '00:23:49,800 --> 00:23:50,800',
#                'text': '        Y me afectÃ³ mucho,'}),
#              (222,
#               {'time': '00:23:52,040 --> 00:23:54,800',
#                'text': '       porque me di cuenta   de que me parezco a mi padre.'}),
#              (223,
#               {'time': '00:23:56,520 --> 00:23:58,160',
#                'text': '  Y sÃ\xad, reconozco que a veces...'}),
#              (224,
#               {'time': '00:23:59,160 --> 00:24:00,920',
#                'text': '  puedo dar un poquito de rabia.'}),
#              (225,
#               {'time': '00:24:02,160 --> 00:24:03,520',
#                'text': '     MÃ¡s bien bastante rabia.'}),
#              (226,
#               {'time': '00:24:04,720 --> 00:24:05,720',
#                'text': '              Mucha.'}),
#              (227,
#               {'time': '00:24:08,160 --> 00:24:09,239',
#                'text': '           Uno a cero.'}),
#              (228,
#               {'time': '00:24:10,000 --> 00:24:11,520',
#                'text': '       Uno a cero Â¿de quÃ©?'}),
#              (229,
#               {'time': '00:24:11,680 --> 00:24:13,439',
#                'text': 'Bueno, te he explicado una cosa...'}),
#              (230,
#               {'time': '00:24:14,040 --> 00:24:16,040',
#                'text': '          personal que,      para mÃ\xad no es agradable.'}),
#              (231,
#               {'time': '00:24:17,400 --> 00:24:18,400',
#                'text': '              Â¿Y tÃº?'}),
#              (232,
#               {'time': '00:24:19,920 --> 00:24:22,840',
#                'text': '    Â¿Tienes algÃºn punto dÃ©bil      que quieras explicarme?'}),
#              (233,
#               {'time': '00:24:40,320 --> 00:24:41,360',
#                'text': '        SegÃºn AristÃ³teles,'}),
#              (234,
#               {'time': '00:24:41,520 --> 00:24:43,840',
#                'text': '     quienes tenÃ\xadan que tener        las mejores flautas'}),
#              (235,
#               {'time': '00:24:44,000 --> 00:24:45,640',
#                'text': '   eran los mejores flautistas.'}),
#              (236,
#               {'time': '00:24:45,800 --> 00:24:47,479',
#                'text': ' Era una manera de recompensarlos'}),
#              (237,
#               {'time': '00:24:47,640 --> 00:24:48,959',
#                'text': '      por su virtud musical.'}),
#              (238,
#               {'time': '00:24:49,600 --> 00:24:51,600',
#                'text': '           En polÃ\xadtica    tambiÃ©n tendrÃ\xada que ser asÃ\xad,'}),
#              (239,
#               {'time': '00:24:51,760 --> 00:24:54,879',
#                'text': 'que los ciudadanos mÃ¡s ejemplares     fuesen los que accediesen'}),
#              (240,
#               {'time': '00:24:55,040 --> 00:24:57,520',
#                'text': '     a los cargos polÃ\xadticos       de mÃ¡s responsabilidad.'}),
#              (241,
#               {'time': '00:24:57,680 --> 00:24:59,800',
#                'text': '       PlatÃ³n y AristÃ³teles        lo tenÃ\xadan muy claro:'}),
#              (242,
#               {'time': '00:24:59,959 --> 00:25:01,680',
#                'text': 'el polÃ\xadtico tiene que ser decente'}),
#              (243,
#               {'time': '00:25:01,840 --> 00:25:05,200',
#                'text': '       porque un indecente   destruye todo lo que gobierna.'}),
#              (244,
#               {'time': '00:25:05,680 --> 00:25:06,680',
#                'text': '           Y vosotros,'}),
#              (245,
#               {'time': '00:25:07,640 --> 00:25:09,920',
#                'text': '         si en un futuro    os dedicaseis a la polÃ\xadtica,'}),
#              (246,
#               {'time': '00:25:10,879 --> 00:25:12,080',
#                'text': '        Â¿serÃ\xadais Ã\xadntegros?'}),
#              (247,
#               {'time': '00:25:13,840 --> 00:25:15,640',
#                'text': 'Todos sabemos que no hay que robar.'}),
#              (248,
#               {'time': '00:25:15,959 --> 00:25:17,520',
#                'text': '  Joder, quÃ© clase tan ejemplar.'}),
#              (249,
#               {'time': '00:25:17,680 --> 00:25:20,879',
#                'text': ' A mÃ\xad si el jefe me paga un extra  en dinero negro, yo "encantao".'}),
#              (250,
#               {'time': '00:25:22,080 --> 00:25:22,959',
#                'text': '            Â¿QuÃ© pasa?'}),
#              (251,
#               {'time': '00:25:23,119 --> 00:25:24,959',
#                'text': '          A ver, Silvia,       el primer dÃ\xada de clase'}),
#              (252,
#               {'time': '00:25:25,119 --> 00:25:27,479',
#                'text': '           nos dijiste que los profes asociados cobrÃ¡is,'}),
#              (253,
#               {'time': '00:25:27,640 --> 00:25:28,760',
#                'text': '      como mucho, 500 euros.'}),
#              (254,
#               {'time': '00:25:28,920 --> 00:25:30,439',
#                'text': 'Veo que quieres alegrarme el dÃ\xada.'}),
#              (255,
#               {'time': '00:25:30,600 --> 00:25:33,320',
#                'text': '          Vale, perdona.  AdemÃ¡s, las tasas universitarias'}),
#              (256,
#               {'time': '00:25:33,479 --> 00:25:34,920',
#                'text': '    son escandalosamente altas'}),
#              (257,
#               {'time': '00:25:35,080 --> 00:25:38,080',
#                'text': ' y a los muchos que pedimos beca,   o aprobamos todo o nos echan.'}),
#              (258,
#               {'time': '00:25:38,239 --> 00:25:40,439',
#                'text': '       Ante este panorama,        Â¿quiÃ©n de vosotros'}),
#              (259,
#               {'time': '00:25:40,600 --> 00:25:43,600',
#                'text': ' rechazarÃ\xada un sobre con dinero?     Vamos, levantad la mano.'}),
#              (260,
#               {'time': '00:25:48,439 --> 00:25:50,800',
#                'text': '           EstÃ¡ claro que no hay que defraudar a Hacienda'}),
#              (261,
#               {'time': '00:25:50,959 --> 00:25:53,600',
#                'text': '   y que los principios morales          deben ser esos,'}),
#              (262,
#               {'time': '00:25:53,760 --> 00:25:56,320',
#                'text': '       pero el problema es que la gente se aleja del sistema'}),
#              (263,
#               {'time': '00:25:56,479 --> 00:25:57,720',
#                'text': '    porque es muy castigador.'}),
#              (264,
#               {'time': '00:25:58,479 --> 00:26:00,320',
#                'text': ' Â¿PodrÃ\xadas explicarlo un poco mÃ¡s?'}),
#              (265,
#               {'time': '00:26:01,160 --> 00:26:02,160',
#                'text': '           Bueno, pues,'}),
#              (266,
#               {'time': '00:26:03,080 --> 00:26:05,040',
#                'text': 'no sÃ©, mi padre hace unos aÃ±os...'}),
#              (267,
#               {'time': '00:26:05,200 --> 00:26:07,800',
#                'text': '      Â¿QuÃ© pasa? De verdad,    hablo en serio. Escuchadme.'}),
#              (268,
#               {'time': '00:26:10,000 --> 00:26:11,600',
#                'text': 'Y a Ã©l, por el hecho de ser puntual'}),
#              (269,
#               {'time': '00:26:11,760 --> 00:26:13,560',
#                'text': '        y trabajar bien,         le pagaban un plus.'}),
#              (270,
#               {'time': '00:26:13,720 --> 00:26:15,920',
#                'text': '            Entonces, Â¿por quÃ© el sistema no recompensa'}),
#              (271,
#               {'time': '00:26:16,080 --> 00:26:17,600',
#                'text': '   a los ciudadanos ejemplares?'}),
#              (272,
#               {'time': '00:26:17,760 --> 00:26:19,760',
#                'text': 'Pagar impuestos es tu obligaciÃ³n.'}),
#              (273,
#               {'time': '00:26:19,920 --> 00:26:21,439',
#                'text': '    De acuerdo, pero insisto,'}),
#              (274,
#               {'time': '00:26:21,600 --> 00:26:24,640',
#                'text': '     hay millones de personas pagando sus impuestos toda su vida'}),
#              (275,
#               {'time': '00:26:24,800 --> 00:26:26,720',
#                'text': '           y al final,     Â¿quÃ© reciben al jubilarse?'}),
#              (276,
#               {'time': '00:26:26,879 --> 00:26:29,520',
#                'text': '      Una pensiÃ³n de mierda.     -Pol, eres un antisistema.'}),
#              (277,
#               {'time': '00:26:29,680 --> 00:26:31,920',
#                'text': '     MarquÃ©s de Casamiquela,       yo adoro el sistema.'}),
#              (278,
#               {'time': '00:26:32,080 --> 00:26:34,479',
#                'text': '  El problema es que el sistema        no me quiere a mÃ\xad.'}),
#              (279,
#               {'time': '00:26:35,800 --> 00:26:36,879',
#                'text': '     Un momento, un momento.'}),
#              (280,
#               {'time': '00:26:37,040 --> 00:26:38,000',
#                'text': '               Pol,'}),
#              (281,
#               {'time': '00:26:38,400 --> 00:26:41,280',
#                'text': '   el sistema tiene que vigilar    y castigar a los corruptos,'}),
#              (282,
#               {'time': '00:26:41,439 --> 00:26:42,879',
#                'text': '  si no, todo se va a la mierda.'}),
#              (283,
#               {'time': '00:26:43,439 --> 00:26:45,439',
#                'text': '  Vamos a ver, Biel, una cosita,'}),
#              (284,
#               {'time': '00:26:45,600 --> 00:26:48,840',
#                'text': '  Â¿a quiÃ©n le interesa un padre o una madre que solamente castigan?'}),
#              (285,
#               {'time': '00:26:49,000 --> 00:26:51,280',
#                'text': '        TambiÃ©n nos gusta    que nos mimen un poco, Â¿no?'}),
#              (286,
#               {'time': '00:26:51,439 --> 00:26:54,720',
#                'text': '   Â¿Y por quÃ© no se recompensan     nuestras buenas acciones?'}),
#              (287,
#               {'time': '00:26:54,879 --> 00:26:57,560',
#                'text': '          Yo me planteo: Â¿no disminuirÃ\xadan los defraudadores'}),
#              (288,
#               {'time': '00:26:57,720 --> 00:27:00,119',
#                'text': '      si nos recompensaran     cuando nos portamos bien?'}),
#              (289,
#               {'time': '00:27:00,280 --> 00:27:01,720',
#                'text': '   Â¿No habrÃ\xada menos corruptos?'}),
#              (290,
#               {'time': '00:27:01,879 --> 00:27:03,680',
#                'text': '         Es una pregunta        que dejo en el aire.'}),
#              (291,
#               {'time': '00:27:03,840 --> 00:27:05,800',
#                'text': '          Sinceramente,       yo, si me paso la vida'}),
#              (292,
#               {'time': '00:27:05,959 --> 00:27:07,959',
#                'text': '             pagando   religiosamente mis impuestos,'}),
#              (293,
#               {'time': '00:27:08,119 --> 00:27:11,000',
#                'text': '       me gustarÃ\xada recibir una carta de Hacienda diciendo...'}),
#              (294,
#               {'time': '00:27:26,119 --> 00:27:27,119',
#                'text': '         No, nada, nada.'}),
#              (295,
#               {'time': '00:27:41,280 --> 00:27:42,640',
#                'text': '    Â¿Quieres que te acompaÃ±e?'}),
#              (296,
#               {'time': '00:27:48,520 --> 00:27:49,520',
#                'text': '            QuÃ© bien.'}),
#              (297,
#               {'time': '00:27:55,560 --> 00:27:56,560',
#                'text': '             Â¿TÃº quÃ©?'}),
#              (298,
#               {'time': '00:27:57,119 --> 00:27:58,239',
#                'text': '             Â¿Resaca?'}),
#              (299,
#               {'time': '00:28:02,119 --> 00:28:05,280',
#                'text': '  Escucha, que lo de ayer ya...         Es que iba fatal.'}),
#              (300,
#               {'time': '00:28:06,840 --> 00:28:09,320',
#                'text': '   Pero bueno, no te engaÃ±arÃ©,        sabÃ\xada lo que hacÃ\xada.'}),
#              (301,
#               {'time': '00:28:10,560 --> 00:28:11,879',
#                'text': '        No pasa nada, Oti.'}),
#              (302,
#               {'time': '00:28:12,400 --> 00:28:14,200',
#                'text': '            Â¿Seguro?     -Claro. Me caes muy bien.'}),
#              (303,
#               {'time': '00:28:14,600 --> 00:28:16,720',
#                'text': '             AdemÃ¡s,   todos tenemos nuestros deseos.'}),
#              (304,
#               {'time': '00:28:19,160 --> 00:28:21,280',
#                'text': '    Quiero que seamos amigos.           -Yo tambiÃ©n.'}),
#              (305,
#               {'time': '00:28:22,200 --> 00:28:23,119',
#                'text': '          Â¿Al final quÃ©?'}),
#              (306,
#               {'time': '00:28:23,280 --> 00:28:25,360',
#                'text': '        Â¿Tenemos el culo      que nos merecemos o no?'}),
#              (307,
#               {'time': '00:28:26,680 --> 00:28:28,640',
#                'text': ' Hola. Venimos a pagar el carnÃ©.'}),
#              (308,
#               {'time': '00:28:37,840 --> 00:28:40,600',
#                'text': '       Ay, chica, es que, en la calle Mandri, Â¿quÃ© esperabas?'}),
#              (309,
#               {'time': '00:28:40,760 --> 00:28:42,560',
#                'text': '  Ve a Ronda Mitre, ya de paso.'}),
#              (310,
#               {'time': '00:28:42,879 --> 00:28:45,280',
#                'text': '     -No tanta risita, Ester,         que no soy tonta.'}),
#              (311,
#               {'time': '00:28:45,439 --> 00:28:46,640',
#                'text': '      Susana, no te enfades.'}),
#              (312,
#               {'time': '00:28:46,800 --> 00:28:49,760',
#                'text': '  Â¿QuÃ© os parece la exposiciÃ³n?       Â¿Vais a comprar algo?'}),
#              (313,
#               {'time': '00:28:51,959 --> 00:28:55,280',
#                'text': '      Oh, compra un cuadro. Tienes las paredes muy aburridas.'}),
#              (314,
#               {'time': '00:28:55,439 --> 00:28:57,840',
#                'text': '     Claro, comprad cuadros,        en vez de robarlos.'}),
#              (315,
#               {'time': '00:29:00,239 --> 00:29:01,600',
#                'text': '   No empecemos, haz el favor.'}),
#              (316,
#               {'time': '00:29:01,760 --> 00:29:04,000',
#                'text': '   Si vienes a decir tonterÃ\xadas,           mejor lÃ¡rgate.'}),
#              (317,
#               {'time': '00:29:04,160 --> 00:29:06,520',
#                'text': '    MamÃ¡, te dije que vendrÃ\xada.         -No estÃ¡ mal, Â¿no?'}),
#              (318,
#               {'time': '00:29:07,160 --> 00:29:08,800',
#                'text': '  Joder, Ester, Â¿y este abrigo?'}),
#              (319,
#               {'time': '00:29:09,400 --> 00:29:10,520',
#                'text': '            Â¿Te gusta?                -SÃ\xad.'}),
#              (320,
#               {'time': '00:29:12,879 --> 00:29:15,680',
#                'text': '           Os presento.     Minerva Picotti. Mi madre,'}),
#              (321,
#               {'time': '00:29:17,040 --> 00:29:18,640',
#                'text': '    mi tÃ\xada Ester y sus amigas.'}),
#              (322,
#               {'time': '00:29:19,680 --> 00:29:21,320',
#                'text': '       Â¿CÃ³mo os llamabais?'}),
#              (323,
#               {'time': '00:29:21,479 --> 00:29:22,439',
#                'text': '          Â¡Rai, quÃ© feo!'}),
#              (324,
#               {'time': '00:29:29,760 --> 00:29:30,760',
#                'text': '           Â¡QuÃ© bonito!'}),
#              (325,
#               {'time': '00:29:33,680 --> 00:29:34,959',
#                'text': '        Â¡Ester, por favor!'}),
#              (326,
#               {'time': '00:29:35,560 --> 00:29:36,920',
#                'text': '     Bueno, estamos por aquÃ\xad.'}),
#              (327,
#               {'time': '00:29:40,360 --> 00:29:41,959',
#                'text': '  En Argentina estÃ¡n fatal, Â¿no?'}),
#              (328,
#               {'time': '00:29:42,119 --> 00:29:45,040',
#                'text': '  Van de corralito en corralito.        -Calla, te va a oÃ\xadr.'}),
#              (329,
#               {'time': '00:29:57,520 --> 00:29:59,160',
#                'text': '  Es que mi madre no me conoce.'}),
#              (330,
#               {'time': '00:29:59,760 --> 00:30:02,600',
#                'text': '       Cuando era pequeÃ±o, nunca me regalaba lo que yo querÃ\xada.'}),
#              (331,
#               {'time': '00:30:03,040 --> 00:30:06,800',
#                'text': ' Si le pedÃ\xada un coche de juguete,       ella mandaba a alguien'}),
#              (332,
#               {'time': '00:30:06,959 --> 00:30:09,400',
#                'text': '           a comprarme un coche grande con motor, Â¿sabes?'}),
#              (333,
#               {'time': '00:30:27,959 --> 00:30:30,160',
#                'text': '            A veces,  echo de menos leer algÃºn libro.'}),
#              (334,
#               {'time': '00:30:34,400 --> 00:30:36,840',
#                'text': '      En el "insti" me leÃ\xad    "El relato de un nÃ¡ufrago".'}),
#              (335,
#               {'time': '00:30:37,360 --> 00:30:39,280',
#                'text': ' Es cortito, pero estÃ¡ bien, Â¿eh?'}),
#              (336,
#               {'time': '00:30:43,119 --> 00:30:44,239',
#                'text': '          Hoy, en clase,'}),
#              (337,
#               {'time': '00:30:44,400 --> 00:30:46,760',
#                'text': '        nos han explicado     el teorema de Weierstrass.'}),
#              (338,
#               {'time': '00:30:52,520 --> 00:30:53,520',
#                'text': '              Â¿AquÃ\xad?'}),
#              (339,
#               {'time': '00:30:59,560 --> 00:31:00,560',
#                'text': '        SegÃºn el teorema,'}),
#              (340,
#               {'time': '00:31:01,280 --> 00:31:03,680',
#                'text': '      si una funciÃ³n efe...'}),
#              (341,
#               {'time': '00:31:03,840 --> 00:31:04,959',
#                'text': '           de equis...'}),
#              (342,
#               {'time': '00:31:05,840 --> 00:31:08,280',
#                'text': '  es continua en un intervalo...'}),
#              (343,
#               {'time': '00:31:08,760 --> 00:31:10,600',
#                'text': '              a, b,'}),
#              (344,
#               {'time': '00:31:12,040 --> 00:31:14,040',
#                'text': '         entonces, efe...'}),
#              (345,
#               {'time': '00:31:14,879 --> 00:31:15,879',
#                'text': '            es acotada'}),
#              (346,
#               {'time': '00:31:16,400 --> 00:31:17,760',
#                'text': '        en este intervalo.'}),
#              (347,
#               {'time': '00:31:18,800 --> 00:31:21,640',
#                'text': '       "Acotada" significa que estÃ¡ limitada por dos nÃºmeros:'}),
#              (348,
#               {'time': '00:31:21,800 --> 00:31:22,800',
#                'text': '          por arriba...'}),
#              (349,
#               {'time': '00:31:25,600 --> 00:31:26,720',
#                'text': '           y por abajo.'}),
#              (350,
#               {'time': '00:31:38,239 --> 00:31:40,760',
#                'text': ' Que yo no quiero que lo vendan.        Lo quiero para mÃ\xad.'}),
#              (351,
#               {'time': '00:31:48,160 --> 00:31:49,920',
#                'text': 'Â¿QuÃ© te pasa? Â¿Por quÃ© no duermes?'}),
#              (352,
#               {'time': '00:32:13,760 --> 00:32:15,840',
#                'text': '        Vale, no, Minerva,        no querÃ\xada decir eso.'}),
#              (353,
#               {'time': '00:32:34,360 --> 00:32:36,479',
#                'text': '     Me han ofrecido trabajo         en un instituto.'}),
#              (354,
#               {'time': '00:32:37,080 --> 00:32:38,200',
#                'text': '        El prÃ³ximo curso.'}),
#              (355,
#               {'time': '00:32:41,400 --> 00:32:42,560',
#                'text': '        CobrarÃ\xada el doble.'}),
#              (356,
#               {'time': '00:32:48,479 --> 00:32:49,879',
#                'text': '      No lo tengo tan claro.'}),
#              (357,
#               {'time': '00:32:50,760 --> 00:32:54,000',
#                'text': '  No sÃ©, la verdad es que aquÃ\xad me siento bien, me siento motivada.'}),
#              (358,
#               {'time': '00:32:54,560 --> 00:32:57,920',
#                'text': ' Y mÃ¡s ahora, que los de primero son mejores que los del aÃ±o pasado.'}),
#              (359,
#               {'time': '00:32:59,040 --> 00:33:00,959',
#                'text': '            Â¡Y tanto!   Hoy en clase se ha organizado'}),
#              (360,
#               {'time': '00:33:01,119 --> 00:33:02,320',
#                'text': '      un debate superchulo,'}),
#              (361,
#               {'time': '00:33:02,479 --> 00:33:03,920',
#                'text': '   no han parado de intervenir.'}),
#              (362,
#               {'time': '00:33:08,840 --> 00:33:10,040',
#                'text': '       No lo digo en broma.'}),
#              (363,
#               {'time': '00:33:11,040 --> 00:33:12,879',
#                'text': '        Tengo la sensaciÃ³n         de que les gusto.'}),
#              (364,
#               {'time': '00:33:13,760 --> 00:33:15,160',
#                'text': '    Por eso dudo en marcharme.'}),
#              (365,
#               {'time': '00:33:16,080 --> 00:33:17,400',
#                'text': '      AquÃ\xad tengo alumnos...'}),
#              (366,
#               {'time': '00:33:18,080 --> 00:33:19,720',
#                'text': '   especialmente interesantes.'}),
#              (367,
#               {'time': '00:33:42,360 --> 00:33:43,720',
#                'text': '       Mola el otoÃ±o, Â¿no?'}),
#              (368,
#               {'time': '00:33:46,200 --> 00:33:47,479',
#                'text': '         Oscurece antes.'}),
#              (369,
#               {'time': '00:33:49,720 --> 00:33:51,760',
#                'text': '         Vale. Â¿Era eso?'}),
#              (370,
#               {'time': '00:33:51,920 --> 00:33:54,800',
#                'text': '      Â¿Hacemos un descanso?         Tengo un cruasÃ¡n.'}),
#              (371,
#               {'time': '00:33:56,200 --> 00:33:58,119',
#                'text': '    Vale. Si me das la mitad.'}),
#              (372,
#               {'time': '00:34:01,160 --> 00:34:02,239',
#                'text': '             DÃ©jalo.'}),
#              (373,
#               {'time': '00:34:02,400 --> 00:34:04,600',
#                'text': 'No, bueno, sÃ\xad, te lo dejarÃ© morder.'}),
#              (374,
#               {'time': '00:34:06,000 --> 00:34:07,479',
#                'text': '   Das bastante risa, tÃº, Â¿eh?'}),
#              (375,
#               {'time': '00:34:08,080 --> 00:34:10,040',
#                'text': '            Â¿Por quÃ©?     Parezco mÃ¡s pequeÃ±o, Â¿no?'}),
#              (376,
#               {'time': '00:34:18,439 --> 00:34:19,959',
#                'text': '     Â¿Te has enamorado o quÃ©?'}),
#              (377,
#               {'time': '00:34:20,119 --> 00:34:21,080',
#                'text': '             Â¡QuÃ© va!'}),
#              (378,
#               {'time': '00:34:21,920 --> 00:34:23,640',
#                'text': ' No puedes enamorarte tan rÃ¡pido.'}),
#              (379,
#               {'time': '00:34:37,840 --> 00:34:39,320',
#                'text': '   Estoy enamorado de Minerva.'}),
#              (380,
#               {'time': '00:34:40,280 --> 00:34:43,000',
#                'text': '    Pero ella prefiere el arte      antes que los cruasanes.'}),
#              (381,
#               {'time': '00:34:45,640 --> 00:34:46,800',
#                'text': '          Â¿DecÃ\xadas algo?'}),
#              (382,
#               {'time': '00:38:26,439 --> 00:38:28,239',
#                'text': '            Â¿QuÃ© tal?           -Bien. Â¿Y tÃº?'}),
#              (383,
#               {'time': '00:38:29,600 --> 00:38:30,600',
#                'text': '          TenÃ\xadas razÃ³n.'}),
#              (384,
#               {'time': '00:38:32,479 --> 00:38:34,600',
#                'text': '     Lo que me hizo la BolaÃ±o        el otro dÃ\xada en clase'}),
#              (385,
#               {'time': '00:38:34,760 --> 00:38:35,760',
#                'text': '         no me molÃ³ nada.'}),
#              (386,
#               {'time': '00:38:38,320 --> 00:38:39,640',
#                'text': '       Me sentÃ\xad humillado.'}),
#              (387,
#               {'time': '00:38:44,640 --> 00:38:46,040',
#                'text': '         Reconozco que...'}),
#              (388,
#               {'time': '00:38:48,239 --> 00:38:49,560',
#                'text': '     que no me gusta perder.'}),
#              (389,
#               {'time': '00:38:52,680 --> 00:38:56,040',
#                'text': '       Y lo que mÃ¡s me jode   es que se sepa que he perdido.'}),
#              (390,
#               {'time': '00:39:03,305 --> 00:40:03,517',
#                'text': 'Por favor califica este subtitulo en www.osdb.link/6y8jb Ayuda a otros a elegir el mejor'})])

# %%
'''
PART 2: JOIN THE TEXT
'''
import re
from datetime import datetime

all_text = ''
prev_time = ''
it = 0
for id, vals in subdata.items():

    text = vals['text'].strip()

    if len(all_text) > 0 and all_text[-1] != '\n':
        all_text += ' '

    if prev_time == '':
        # take the last time of the sequence
        prev_time = re.findall(r'(\d\d:\d\d:\d\d)', vals['time'])[-1]

    # check if a lot of time has passed since the last text. if so, this is a new sentence
    # get current time, first time of this line
    current_time = re.findall(r'(\d\d:\d\d:\d\d)', vals['time'])[0]
    tdelta = (datetime.strptime(current_time, '%H:%M:%S') - datetime.strptime(prev_time, '%H:%M:%S')).total_seconds()
    if int(tdelta) > 10 and all_text[-1] != '\n':
        all_text += '\n' + text
        it += 1
    else:
        all_text += text
    subdata[id]['map'] = it

    # check if text ends in punctuation. if so, it's the end of the sentence
    if text.rstrip('</i>')[-1] in ['.', '?', '!', ')']:
        all_text += '\n'
        it += 1
    
    prev_time = re.findall(r'(\d\d:\d\d:\d\d)', vals['time'])[-1]

all_text = all_text.split('\n')
'''
with open('ex.txt', 'w') as f:
    f.write(all_text)
'''
if all_text[-1] == '':
    all_text = all_text[:-1]
all_text[:20]
# Out:
# ['Ella dijo que me podia dar un regalo cuando yo vuelva.',
#  'Y tambien dijo que hoy es jueves.',
#  'Roja.',
#  'Rojo.                -Roja.',
#  'Roja.',
#  'Roja.',
#  'Hostia,  Â¿habÃ©is visto el campus virtual?',
#  'Hoy la clase de Cultura        es en el aula 110.',
#  'Pues vamos para allÃ¡,    que si no, no habrÃ¡ sitio...',
#  'No, desayunamos,       nos relajamos y ya...',
#  'Bueno, ya tenÃ\xada ganas  de sentarme con mis compaÃ±eros, que me meten     puÃ±aladas por la espalda.',
#  'Â¿No estÃ¡s enfadado?          -Â¿Yo? Â¡QuÃ© va!',
#  'El ejercicio es buenÃ\xadsimo.',
#  'AdemÃ¡s, la BolaÃ±o es la bomba como profe.',
#  'Pero a ver, explicÃ¡dmelo.',
#  'O sea, Â¿ella os ha dicho   que yo llegarÃ\xada tarde a clase?',
#  'No, no. Nos ha dicho   que si alguien llegaba tarde, nos preguntarÃ\xada       el color de la carpeta y que dijÃ©ramos rojo.               -SÃ\xad.',
#  'Es que si lo piensas, es buenÃ\xadsimo.',
#  'Pero tiene un puntito cruel.',
#  'No lo dirÃ¡s por mÃ\xad.          -Bueno, pues...']

# %%
from transformers import pipeline
model_checkpoint = "Helsinki-NLP/opus-mt-es-en"
translator = pipeline("translation", model=model_checkpoint)

# %%
'''
translated_text = []
for sentence in all_text:
    translated = translator(sentence)[0]['translation_text']
    #print(translated)
    translated_text.append(translated)
'''
translated_text = [translator(sentence)[0]['translation_text'] for sentence in all_text[:5]]

# %%
translator('Ella dijo que me podia dar un regalo cuando yo vuelva. Y tambien dijo que hoy es jueves.')
# Out:
# [{'translation_text': "She said she could give me a present when I get back, and she also said it's Thursday."}]

# %%
translated_text
# Out:
# ['She said she could give me a present when I get back.',
#  'And he also said that today is Thursday.',
#  'Red.',
#  'Red.',
#  'Red.']

# %%
import transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-es-en")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-es-en")

# %%
text = '<SEP> '.join(all_text)
tokenized_text = tokenizer.prepare_seq2seq_batch([text], return_tensors='pt')
translation = model.generate(**tokenized_text)
translated_text = tokenizer.batch_decode(translation, skip_special_tokens=False)[0]
translated_text = translated_text.split('<SEP> ')
translated_text
# Out:
# ["<pad> You're the one who won't answer my calls! ",
#  "Don't complain, baby! ",
#  'See if I start working and let my head rest. ',
#  "I've been told that if I take my driver's license, I could work in a parking lot parking cars, watching... A party! ",
#  "Total, I don't know what the fuck to do with my life. ",
#  "I'll do the selectivity and study history. ",
#  'I already have enough with my grandmother\'s "depre". ',
#  'And if I call you, Pol Rubio, take my mobile phone. ',
#  'I close at home to cry all day? ',
#  'I tried to keep with my life. ',
#  'I already have enough with my grandmother\'s "depre".']

# %%
len(translated_text)
# Out:
# 11

# %%
'''
PART 4: replace translated text in the sub file

dummy mode: replace all excerpts of a "sentence" by the whole translated sentence
since we have no alignments
'''
transdata = OrderedDict()
for key, vals in subdata.items():
    transdata[key] = {
        'time': vals['time'],
        'text': translated_text[vals['map']]
    }

transdata
# Out:
# OrderedDict([(2, {'time': '00:01:04,560 --> 00:01:05,520', 'text': 'Red.'}),
#              (3, {'time': '00:01:10,040 --> 00:01:11,160', 'text': 'Red.'}),
#              (4, {'time': '00:01:14,000 --> 00:01:15,000', 'text': 'Red.'}),
#              (5, {'time': '00:01:15,400 --> 00:01:16,360', 'text': 'Red.'}),
#              (6, {'time': '00:01:17,119 --> 00:01:18,560', 'text': 'Red.'}),
#              (7, {'time': '00:01:20,000 --> 00:01:21,040', 'text': 'Red.'}),
#              (8, {'time': '00:01:27,160 --> 00:01:28,160', 'text': 'Red.'}),
#              (9,
#               {'time': '00:03:35,879 --> 00:03:38,119',
#                'text': 'Holy shit, have you seen the virtual campus?'}),
#              (10,
#               {'time': '00:03:38,280 --> 00:03:40,400',
#                'text': 'Today the Culture class is in classroom 110.'}),
#              (11,
#               {'time': '00:03:41,920 --> 00:03:44,400',
#                'text': "Well, let's go over there, otherwise there won't be any room..."}),
#              (12,
#               {'time': '00:03:44,560 --> 00:03:46,560',
#                'text': 'No, we had breakfast, we relaxed and already...'}),
#              (13,
#               {'time': '00:03:46,720 --> 00:03:49,439',
#                'text': "Well, I was already in the mood to sit down with my fellows, who'd stick their hands in my back."}),
#              (14,
#               {'time': '00:03:49,600 --> 00:03:51,560',
#                'text': "Well, I was already in the mood to sit down with my fellows, who'd stick their hands in my back."}),
#              (15,
#               {'time': '00:03:51,720 --> 00:03:53,479',
#                'text': "Aren't you angry?"}),
#              (16,
#               {'time': '00:03:53,640 --> 00:03:55,000',
#                'text': 'The exercise is good.'}),
#              (17,
#               {'time': '00:03:55,160 --> 00:03:57,200',
#                'text': 'In addition, the Ball is the bomb as a teacher.'}),
#              (18,
#               {'time': '00:03:57,360 --> 00:03:58,720',
#                'text': "But let's see, explain it to me."}),
#              (19,
#               {'time': '00:03:58,879 --> 00:04:01,600',
#                'text': "I mean, did she tell you I'd be late for class?"}),
#              (20,
#               {'time': '00:04:01,760 --> 00:04:04,200',
#                'text': 'No, no. He told us that if someone was late, he would ask us the color of the folder and that we would say red.'}),
#              (21,
#               {'time': '00:04:04,360 --> 00:04:06,280',
#                'text': 'No, no. He told us that if someone was late, he would ask us the color of the folder and that we would say red.'}),
#              (22,
#               {'time': '00:04:06,439 --> 00:04:07,760',
#                'text': 'No, no. He told us that if someone was late, he would ask us the color of the folder and that we would say red.'}),
#              (23,
#               {'time': '00:04:07,920 --> 00:04:09,640',
#                'text': "It's just that if you think about it, it's good."}),
#              (24,
#               {'time': '00:04:11,119 --> 00:04:12,600',
#                'text': "But he's got a cruel little dot."}),
#              (25,
#               {'time': '00:04:13,119 --> 00:04:14,959',
#                'text': "You won't say it for me."}),
#              (26,
#               {'time': '00:04:15,119 --> 00:04:17,479',
#                'text': "I'm going there, and then there won't be room and there won't be..."}),
#              (27,
#               {'time': '00:04:17,640 --> 00:04:18,680',
#                'text': 'Save for everyone.'}),
#              (28,
#               {'time': '00:04:20,520 --> 00:04:22,920',
#                'text': "But there's class at 110?"}),
#              (29,
#               {'time': '00:04:28,840 --> 00:04:30,280',
#                'text': 'How do you like to play, huh?'}),
#              (30,
#               {'time': '00:04:30,439 --> 00:04:31,840',
#                'text': 'To the ball more.'}),
#              (31,
#               {'time': '00:04:51,320 --> 00:04:53,200',
#                'text': 'And now, repeat all with me.'}),
#              (32,
#               {'time': '00:05:02,800 --> 00:05:03,840',
#                'text': 'Once again.'}),
#              (33,
#               {'time': '00:05:12,560 --> 00:05:14,560',
#                'text': "You know, I don't think you're that calm."}),
#              (34,
#               {'time': '00:05:14,720 --> 00:05:17,720',
#                'text': 'After the "momentazo" that made you pass the Ball...'}),
#              (35,
#               {'time': '00:05:17,879 --> 00:05:20,800',
#                'text': "- No, man, but first it doesn't fix your job, now this..."}),
#              (36,
#               {'time': '00:05:20,959 --> 00:05:22,959',
#                'text': "- No, man, but first it doesn't fix your job, now this..."}),
#              (37,
#               {'time': '00:05:23,119 --> 00:05:25,959',
#                'text': "What's wrong with you?"}),
#              (38,
#               {'time': '00:05:26,119 --> 00:05:28,160',
#                'text': 'But you followed the game, that pisses me off.'}),
#              (39,
#               {'time': '00:05:28,320 --> 00:05:30,920',
#                'text': 'You could have told me he was going to play with me.'}),
#              (40,
#               {'time': '00:05:31,080 --> 00:05:33,239',
#                'text': 'First you go as a friend, but then, take it!'}),
#              (41,
#               {'time': '00:05:33,400 --> 00:05:35,680',
#                'text': "Don't be mad, we'll have a beer tonight and we'll disconnect."}),
#              (42,
#               {'time': '00:05:36,479 --> 00:05:37,840',
#                'text': "Don't be mad, we'll have a beer tonight and we'll disconnect."}),
#              (43, {'time': '00:05:38,520 --> 00:05:39,479', 'text': 'Okay.'}),
#              (44,
#               {'time': '00:05:39,640 --> 00:05:41,439',
#                'text': '- On the floor of Minerva.'}),
#              (45,
#               {'time': '00:05:42,200 --> 00:05:45,000',
#                'text': "I just talked to her, she's got a beautiful terrace."}),
#              (46,
#               {'time': '00:05:45,160 --> 00:05:47,840',
#                'text': "I'll tell you, I'm keeping track of working hours."}),
#              (47,
#               {'time': '00:05:48,320 --> 00:05:51,200',
#                'text': 'Dude, what are you doing in a fucking parking lot?'}),
#              (48,
#               {'time': '00:05:51,640 --> 00:05:54,520',
#                'text': 'Do as Minerva, quit the job.'}),
#              (49,
#               {'time': '00:07:25,239 --> 00:07:26,720', 'text': 'Hi, Rai.'}),
#              (50,
#               {'time': '00:07:29,360 --> 00:07:30,360', 'text': "What's up?"}),
#              (51,
#               {'time': '00:07:31,080 --> 00:07:32,600',
#                'text': "How's it going, Schopenhauer?"}),
#              (52,
#               {'time': '00:07:33,560 --> 00:07:34,840',
#                'text': "We haven't gotten to him yet."}),
#              (53,
#               {'time': '00:07:35,959 --> 00:07:38,119',
#                'text': 'I also know a little bit of philosophy.'}),
#              (54,
#               {'time': '00:07:38,280 --> 00:07:39,400',
#                'text': 'I think so.'}),
#              (55,
#               {'time': '00:07:40,720 --> 00:07:42,080',
#                'text': "Your mother's in the garden."}),
#              (56,
#               {'time': '00:07:45,119 --> 00:07:46,400',
#                'text': 'Distracted, reading...'}),
#              (57,
#               {'time': '00:08:04,720 --> 00:08:06,800',
#                'text': 'Where the hell is Saint Peter of Verona?'}),
#              (58, {'time': '00:08:07,720 --> 00:08:08,800', 'text': 'Mom!'}),
#              (59,
#               {'time': '00:08:10,360 --> 00:08:12,119',
#                'text': 'Is it true you stole my painting?'}),
#              (60,
#               {'time': '00:08:14,600 --> 00:08:16,520',
#                'text': "You're talking about robbery?"}),
#              (61,
#               {'time': '00:08:16,680 --> 00:08:18,320',
#                'text': "Did you steal it from the grandparents by taking advantage of the fact that they were at Calella's house?"}),
#              (62,
#               {'time': '00:08:18,479 --> 00:08:20,879',
#                'text': "Did you steal it from the grandparents by taking advantage of the fact that they were at Calella's house?"}),
#              (63,
#               {'time': '00:08:21,040 --> 00:08:22,040',
#                'text': 'I saved the painting.'}),
#              (64,
#               {'time': '00:08:22,200 --> 00:08:24,080',
#                'text': "Your husband would've taken out four tough ones."}),
#              (65,
#               {'time': '00:08:24,239 --> 00:08:25,439',
#                'text': "Are you trying to justify you breaking into grandparents' house?"}),
#              (66,
#               {'time': '00:08:25,600 --> 00:08:27,840',
#                'text': "Are you trying to justify you breaking into grandparents' house?"}),
#              (67,
#               {'time': '00:08:28,760 --> 00:08:31,000',
#                'text': "Let's calm down a little? -An Italian expert in Baroque painting will go to the auction house in Madrid."}),
#              (68,
#               {'time': '00:08:31,160 --> 00:08:33,720',
#                'text': "Let's calm down a little? -An Italian expert in Baroque painting will go to the auction house in Madrid."}),
#              (69,
#               {'time': '00:08:33,879 --> 00:08:36,160',
#                'text': "Julia wants me to certify if the painting can be attributed to Claudio Coello. I don't know if you know who it is."}),
#              (70,
#               {'time': '00:08:36,320 --> 00:08:39,400',
#                'text': "Julia wants me to certify if the painting can be attributed to Claudio Coello. I don't know if you know who it is."}),
#              (71,
#               {'time': '00:08:39,640 --> 00:08:40,840',
#                'text': 'Look, two little things.'}),
#              (72,
#               {'time': '00:08:41,080 --> 00:08:44,360',
#                'text': 'First, Julia get fucked, yeah, fuck Julia.'}),
#              (73,
#               {'time': '00:08:44,520 --> 00:08:47,200',
#                'text': 'And second, you send the Italian a picture and shit.'}),
#              (74,
#               {'time': '00:08:47,360 --> 00:08:49,479',
#                'text': 'Is this the philosophy of your new career?'}),
#              (75,
#               {'time': '00:08:49,640 --> 00:08:52,560',
#                'text': '- Will you shut up, please?'}),
#              (76,
#               {'time': '00:08:52,720 --> 00:08:55,119',
#                'text': "Victoria, it's attributable to Coello. I told you, it looks a lot like the Santo Domingo Museum in Budapest."}),
#              (77,
#               {'time': '00:08:55,280 --> 00:08:58,080',
#                'text': "Victoria, it's attributable to Coello. I told you, it looks a lot like the Santo Domingo Museum in Budapest."}),
#              (78,
#               {'time': '00:08:58,239 --> 00:08:59,920',
#                'text': "Maybe the Italian won't be necessary."}),
#              (79,
#               {'time': '00:09:07,800 --> 00:09:09,920',
#                'text': "Now all of a sudden you're interested in painting?"}),
#              (80,
#               {'time': '00:09:10,080 --> 00:09:11,920',
#                'text': "If you don't even come near the auction house."}),
#              (81,
#               {'time': '00:09:12,080 --> 00:09:13,600',
#                'text': 'Look, let the painting stay.'}),
#              (82,
#               {'time': '00:09:15,200 --> 00:09:18,320',
#                'text': 'And tomorrow you come to the inauguration of the new exhibition.'}),
#              (83,
#               {'time': '00:09:18,760 --> 00:09:21,800',
#                'text': "So you show a little interest in mom's work."}),
#              (84,
#               {'time': '00:09:23,239 --> 00:09:24,959',
#                'text': "And I don't like you talking to him like that."}),
#              (85,
#               {'time': '00:09:25,920 --> 00:09:27,720',
#                'text': "You're going, huh, Rai?"}),
#              (86,
#               {'time': '00:09:32,600 --> 00:09:33,760', 'text': "I'm going."}),
#              (87,
#               {'time': '00:10:11,320 --> 00:10:12,600',
#                'text': 'Until tomorrow. -Bye.'}),
#              (88,
#               {'time': '00:10:27,239 --> 00:10:28,879',
#                'text': "No, Gloria, I don't understand classical music and stuff."}),
#              (89,
#               {'time': '00:10:29,040 --> 00:10:31,560',
#                'text': "No, Gloria, I don't understand classical music and stuff."}),
#              (90,
#               {'time': '00:10:32,040 --> 00:10:34,640',
#                'text': "- I'm tired of arguing."}),
#              (91,
#               {'time': '00:10:36,520 --> 00:10:37,720', 'text': "It's okay."}),
#              (92,
#               {'time': '00:10:38,119 --> 00:10:39,560',
#                'text': 'Enjoy the concert.'}),
#              (93,
#               {'time': '00:10:41,200 --> 00:10:42,439',
#                'text': 'Gloria, you look beautiful.'}),
#              (94,
#               {'time': '00:10:42,600 --> 00:10:44,280',
#                'text': 'Thank you, at least you tell me.'}),
#              (95,
#               {'time': '00:10:44,840 --> 00:10:47,520',
#                'text': "What's the first thing I told you?"}),
#              (96,
#               {'time': '00:10:47,680 --> 00:10:50,439',
#                'text': "Your father doesn't want to accompany me to a piano concert."}),
#              (97,
#               {'time': '00:10:56,119 --> 00:10:58,720',
#                'text': "See if you calm him down, I can't and I'll be late."}),
#              (98,
#               {'time': '00:10:58,879 --> 00:10:59,879',
#                'text': "I'm leaving, too."}),
#              (99,
#               {'time': '00:12:08,600 --> 00:12:10,479',
#                'text': "Look who I've met."}),
#              (100,
#               {'time': '00:12:12,680 --> 00:12:13,760', 'text': 'All right.'}),
#              (101,
#               {'time': '00:12:13,920 --> 00:12:15,640',
#                'text': "Well, what a pimp this is, isn't it?"}),
#              (102,
#               {'time': '00:12:19,320 --> 00:12:20,760',
#                'text': "It's a fucking guy."}),
#              (103,
#               {'time': '00:12:20,920 --> 00:12:22,959',
#                'text': 'Funny, French, pianist...'}),
#              (104,
#               {'time': '00:12:23,119 --> 00:12:24,400',
#                'text': "Well, he's got everything, isn't he?"}),
#              (105,
#               {'time': '00:12:25,439 --> 00:12:26,800',
#                'text': 'And Rai with whom does he speak?'}),
#              (106,
#               {'time': '00:12:27,400 --> 00:12:29,119',
#                'text': 'You have to meet her.'}),
#              (107,
#               {'time': '00:12:29,280 --> 00:12:30,320',
#                'text': 'It\'s a "person."'}),
#              (108,
#               {'time': '00:12:32,680 --> 00:12:33,680', 'text': '- Hey.'}),
#              (109,
#               {'time': '00:12:35,320 --> 00:12:37,080',
#                'text': "Amy O'Connor, I'm from Eugene, Origin."}),
#              (110,
#               {'time': '00:12:37,520 --> 00:12:39,640',
#                'text': "Watch out he's got a gun under his pillow."}),
#              (111,
#               {'time': '00:12:39,800 --> 00:12:40,760',
#                'text': '- Okay, listen.'}),
#              (112,
#               {'time': '00:12:41,680 --> 00:12:42,680',
#                'text': 'No, of course.'}),
#              (113,
#               {'time': '00:12:42,879 --> 00:12:43,879',
#                'text': '- I said...'}),
#              (114,
#               {'time': '00:12:46,760 --> 00:12:47,840',
#                'text': 'Like a tradition.'}),
#              (115,
#               {'time': '00:12:48,000 --> 00:12:49,720',
#                'text': 'A tradition, like Halloween, right?'}),
#              (116,
#               {'time': '00:12:50,760 --> 00:12:53,600',
#                'text': "- I know it's not the same, you don't understand because you don't listen."}),
#              (117,
#               {'time': '00:13:00,400 --> 00:13:01,640',
#                'text': 'Pol, listen.'}),
#              (118,
#               {'time': '00:13:06,920 --> 00:13:08,320',
#                'text': 'No, wait a minute, wait a minute.'}),
#              (119,
#               {'time': '00:13:08,479 --> 00:13:10,800',
#                'text': 'Not bad, no, the question. Think a little.'}),
#              (120,
#               {'time': '00:13:16,760 --> 00:13:19,000',
#                'text': 'You call the police and wait?'}),
#              (121,
#               {'time': '00:13:20,560 --> 00:13:23,520',
#                'text': "I'm sorry about your family, but they're all dead."}),
#              (122,
#               {'time': '00:13:24,840 --> 00:13:26,800',
#                'text': 'My father has a hunting shotgun...'}),
#              (123,
#               {'time': '00:13:26,959 --> 00:13:30,280',
#                'text': "I mean, if he comes in and steals from you, they wouldn't steal anything from me."}),
#              (124,
#               {'time': '00:13:30,439 --> 00:13:32,400',
#                'text': 'Does family deserve you to kill for them?'}),
#              (125,
#               {'time': '00:13:32,560 --> 00:13:35,119',
#                'text': "Okay, guys, that's enough. I've got the final debate."}),
#              (126,
#               {'time': '00:13:35,280 --> 00:13:37,520',
#                'text': '- Do we have the ass we deserve?'}),
#              (127, {'time': '00:13:37,680 --> 00:13:38,920', 'text': 'I do.'}),
#              (128, {'time': '00:13:39,080 --> 00:13:40,040', 'text': 'I do.'}),
#              (129,
#               {'time': '00:13:40,680 --> 00:13:41,720',
#                'text': 'Play, play.'}),
#              (130,
#               {'time': '00:13:42,160 --> 00:13:43,879',
#                'text': '- I love it.'}),
#              (131,
#               {'time': '00:13:44,040 --> 00:13:45,479',
#                'text': "Don't I have a good ass?"}),
#              (132,
#               {'time': '00:13:45,640 --> 00:13:47,560',
#                'text': "It's nice, isn't it?"}),
#              (133,
#               {'time': '00:14:54,360 --> 00:14:55,360', 'text': '- Bye.'}),
#              (134,
#               {'time': '00:15:45,160 --> 00:15:47,239',
#                'text': 'Fuck, Pol, are you yawning already, man?'}),
#              (135,
#               {'time': '00:15:48,680 --> 00:15:51,200',
#                'text': "That's why you'd better not come, stay home."}),
#              (136,
#               {'time': '00:15:57,879 --> 00:16:00,080',
#                'text': 'The butler is waiting for you at the door, or what?'}),
#              (137,
#               {'time': '00:16:00,720 --> 00:16:02,040',
#                'text': 'I came by myself.'}),
#              (138,
#               {'time': '00:16:02,479 --> 00:16:04,400',
#                'text': 'Did you get the subway?'}),
#              (139,
#               {'time': '00:16:05,520 --> 00:16:06,720',
#                'text': "Don't get too attached, man."}),
#              (140,
#               {'time': '00:16:06,879 --> 00:16:09,119',
#                'text': 'Be happy, put your money on a chauffeur.'}),
#              (141,
#               {'time': '00:16:09,280 --> 00:16:11,959',
#                'text': "You're one of those who think money is happiness, aren't you?"}),
#              (142,
#               {'time': '00:16:12,119 --> 00:16:13,119',
#                'text': "I don't know."}),
#              (143,
#               {'time': '00:16:14,360 --> 00:16:15,640',
#                'text': 'What do you think?'}),
#              (144,
#               {'time': '00:16:17,479 --> 00:16:18,600', 'text': 'I think...'}),
#              (145,
#               {'time': '00:16:19,760 --> 00:16:21,800',
#                'text': "I'm the only philosophy student who doesn't care if the career has a way out."}),
#              (146,
#               {'time': '00:16:21,959 --> 00:16:24,439',
#                'text': "I'm the only philosophy student who doesn't care if the career has a way out."}),
#              (147,
#               {'time': '00:16:28,959 --> 00:16:30,320',
#                'text': 'Go on, go on.'}),
#              (148,
#               {'time': '00:16:30,479 --> 00:16:31,600',
#                'text': "Well, it's very simple."}),
#              (149,
#               {'time': '00:16:32,280 --> 00:16:34,879',
#                'text': "There are things in my life that don't work, but..."}),
#              (150,
#               {'time': '00:16:35,600 --> 00:16:36,959',
#                'text': "I'm so relaxed!"}),
#              (151,
#               {'time': '00:16:38,680 --> 00:16:40,479',
#                'text': "No, there's more, there's still more."}),
#              (152,
#               {'time': '00:16:41,400 --> 00:16:42,720',
#                'text': "When we're 40 years old, you'll look... 50 and me, 35."}),
#              (153,
#               {'time': '00:16:43,320 --> 00:16:45,239',
#                'text': "When we're 40 years old, you'll look... 50 and me, 35."}),
#              (154,
#               {'time': '00:16:46,200 --> 00:16:47,439',
#                'text': "When we're 40 years old, you'll look... 50 and me, 35."}),
#              (155,
#               {'time': '00:16:55,720 --> 00:16:58,560',
#                'text': 'What bulbs? The green ones or the red ones?'}),
#              (156,
#               {'time': '00:16:59,000 --> 00:17:01,360',
#                'text': "Can you help me, Pol, I don't know right now, I don't..."}),
#              (157,
#               {'time': '00:17:01,520 --> 00:17:02,879',
#                'text': 'Who were you a year ago?'}),
#              (158,
#               {'time': '00:17:04,040 --> 00:17:05,560',
#                'text': 'Who were you?'}),
#              (159,
#               {'time': '00:17:07,080 --> 00:17:09,200',
#                'text': 'Who were you with?'}),
#              (160,
#               {'time': '00:17:09,360 --> 00:17:10,520',
#                'text': "Didn't you have any posh friends?"}),
#              (161,
#               {'time': '00:17:11,400 --> 00:17:14,040',
#                'text': "Yeah, yeah, I'm expired."}),
#              (162,
#               {'time': '00:17:14,200 --> 00:17:16,520',
#                'text': 'What are you doing? Are you looking for friends among the poor?'}),
#              (163,
#               {'time': '00:17:16,680 --> 00:17:19,400',
#                'text': "Why do you get so low? Isn't that what you need us for?"}),
#              (164,
#               {'time': '00:17:19,560 --> 00:17:20,560',
#                'text': "Impossible, isn't it?"}),
#              (165,
#               {'time': '00:17:21,119 --> 00:17:22,360',
#                'text': 'You could be home, without stress, slowly aging and surrounded by the family.'}),
#              (166,
#               {'time': '00:17:22,520 --> 00:17:25,720',
#                'text': 'You could be home, without stress, slowly aging and surrounded by the family.'}),
#              (167,
#               {'time': '00:17:55,360 --> 00:17:56,320',
#                'text': "Hey, Pol, don't fuck off!"}),
#              (168,
#               {'time': '00:17:56,479 --> 00:17:57,800',
#                'text': "Hey, Pol, don't fuck off!"}),
#              (169,
#               {'time': '00:17:57,959 --> 00:18:00,040',
#                'text': '- No, no, stay.'}),
#              (170,
#               {'time': '00:18:00,640 --> 00:18:03,400',
#                'text': 'Stay, I stole a beer from the American.'}),
#              (171,
#               {'time': '00:18:04,320 --> 00:18:06,320',
#                'text': "See if there's any luck and we don't get shot."}),
#              (172,
#               {'time': '00:18:07,600 --> 00:18:09,000',
#                'text': 'Long live Mississippi!'}),
#              (173,
#               {'time': '00:18:12,160 --> 00:18:13,239',
#                'text': 'You, today in class, when the Ball has done the folder exercise, I wanted to hug you.'}),
#              (174,
#               {'time': '00:18:14,000 --> 00:18:15,040',
#                'text': 'You, today in class, when the Ball has done the folder exercise, I wanted to hug you.'}),
#              (175,
#               {'time': '00:18:15,200 --> 00:18:17,959',
#                'text': 'You, today in class, when the Ball has done the folder exercise, I wanted to hug you.'}),
#              (176,
#               {'time': '00:18:19,439 --> 00:18:20,439',
#                'text': 'You, today in class, when the Ball has done the folder exercise, I wanted to hug you.'}),
#              (177,
#               {'time': '00:18:21,920 --> 00:18:22,920',
#                'text': "Look, that's it."}),
#              (178,
#               {'time': '00:18:25,439 --> 00:18:26,920',
#                'text': 'Okay, okay.'}),
#              (179,
#               {'time': '00:18:30,200 --> 00:18:31,879', 'text': 'Oti... go.'}),
#              (180,
#               {'time': '00:18:33,840 --> 00:18:36,040',
#                'text': 'Okay. All right, all right, please!'}),
#              (181,
#               {'time': '00:18:36,479 --> 00:18:39,239',
#                'text': "I like you very much, but I don't want anything with you, okay?"}),
#              (182,
#               {'time': '00:18:41,680 --> 00:18:45,239',
#                'text': "I just think Amy's beer goes up a lot."}),
#              (183,
#               {'time': '00:18:45,920 --> 00:18:46,959', 'text': "It's okay."}),
#              (184,
#               {'time': '00:18:48,040 --> 00:18:50,040',
#                'text': 'You can go upstairs and give you some air.'}),
#              (185,
#               {'time': '00:18:51,200 --> 00:18:53,720',
#                'text': "No, no, I'd better go home."}),
#              (186,
#               {'time': '00:19:15,320 --> 00:19:18,200',
#                'text': "- It's not uncommon for us to throw the shingles at you."}),
#              (187,
#               {'time': '00:19:19,239 --> 00:19:20,600',
#                'text': "I don't understand French."}),
#              (188,
#               {'time': '00:19:27,640 --> 00:19:28,720',
#                'text': 'I understand.'}),
#              (189,
#               {'time': '00:19:42,439 --> 00:19:44,320',
#                'text': 'The Catalans are very discreet.'}),
#              (190,
#               {'time': '00:20:22,000 --> 00:20:23,320',
#                'text': "How's the party?"}),
#              (191, {'time': '00:20:24,040 --> 00:20:25,080', 'text': 'Good.'}),
#              (192,
#               {'time': '00:20:27,560 --> 00:20:29,520',
#                'text': 'Oh, he called Oriol.'}),
#              (193,
#               {'time': '00:20:30,720 --> 00:20:32,600',
#                'text': "Don't call him Oriol, who's my father."}),
#              (194,
#               {'time': '00:20:32,879 --> 00:20:34,879',
#                'text': "I'd like to know if we'll be up on Sunday."}),
#              (195,
#               {'time': '00:20:35,520 --> 00:20:36,920',
#                'text': "They're setting up a barbecue."}),
#              (196,
#               {'time': '00:20:37,600 --> 00:20:39,600',
#                'text': "No, I don't want to go."}),
#              (197,
#               {'time': '00:20:40,360 --> 00:20:43,239',
#                'text': "It's just that my father gives me a stick with his monologues on football."}),
#              (198,
#               {'time': '00:20:43,640 --> 00:20:44,640',
#                'text': "You've had a drink, haven't you?"}),
#              (199,
#               {'time': '00:20:46,360 --> 00:20:47,439',
#                'text': 'A little bit.'}),
#              (200,
#               {'time': '00:20:53,360 --> 00:20:55,600',
#                'text': "Well, I'd love to go up to town."}),
#              (201,
#               {'time': '00:20:55,760 --> 00:20:57,160',
#                'text': "Let's see people."}),
#              (202,
#               {'time': '00:20:58,520 --> 00:21:00,800',
#                'text': 'Fuck, what "heavy"!'}),
#              (203,
#               {'time': '00:21:00,959 --> 00:21:02,239',
#                'text': "I'm staying here."}),
#              (204,
#               {'time': '00:21:03,560 --> 00:21:04,879',
#                'text': "It's just that I've discovered..."}),
#              (205,
#               {'time': '00:21:05,600 --> 00:21:07,160',
#                'text': "I'm cosmopolitan."}),
#              (206,
#               {'time': '00:21:08,119 --> 00:21:09,800',
#                'text': "It's confirmed: you've been drinking."}),
#              (207,
#               {'time': '00:21:11,560 --> 00:21:14,280',
#                'text': 'Come on, let\'s go to sleep. "No, you sleep here, I want to sleep wide in bed.'}),
#              (208,
#               {'time': '00:21:14,439 --> 00:21:16,520',
#                'text': 'Come on, let\'s go to sleep. "No, you sleep here, I want to sleep wide in bed.'}),
#              (209,
#               {'time': '00:21:16,760 --> 00:21:18,320',
#                'text': 'And so I put myself on a cross, and undo it when I feel like it.'}),
#              (210,
#               {'time': '00:21:18,479 --> 00:21:20,560',
#                'text': 'And so I put myself on a cross, and undo it when I feel like it.'}),
#              (211,
#               {'time': '00:21:23,000 --> 00:21:24,600',
#                'text': "And you're going to leave me alone?"}),
#              (212,
#               {'time': '00:21:30,360 --> 00:21:32,520',
#                'text': 'It makes me so bad that you have some gray hair...'}),
#              (213,
#               {'time': '00:21:32,680 --> 00:21:34,000', 'text': 'Oh, yeah?'}),
#              (214,
#               {'time': '00:23:24,520 --> 00:23:26,320',
#                'text': "Sorry, you can't sit here."}),
#              (215,
#               {'time': '00:23:26,920 --> 00:23:28,959',
#                'text': "Looks like an 80-year-old lady died who came as a listener and didn't..."}),
#              (216,
#               {'time': '00:23:29,119 --> 00:23:30,800',
#                'text': "Looks like an 80-year-old lady died who came as a listener and didn't..."}),
#              (217,
#               {'time': '00:23:39,200 --> 00:23:41,400',
#                'text': "Don't you want to know what he did a year ago?"}),
#              (218,
#               {'time': '00:23:43,200 --> 00:23:44,600',
#                'text': 'A year ago, I realized that my father cheated on my grandfather to steal his company.'}),
#              (219,
#               {'time': '00:23:45,360 --> 00:23:47,560',
#                'text': 'A year ago, I realized that my father cheated on my grandfather to steal his company.'}),
#              (220,
#               {'time': '00:23:47,720 --> 00:23:49,040',
#                'text': 'A year ago, I realized that my father cheated on my grandfather to steal his company.'}),
#              (221,
#               {'time': '00:23:49,800 --> 00:23:50,800',
#                'text': 'And I was very touched, because I realized that I look like my father.'}),
#              (222,
#               {'time': '00:23:52,040 --> 00:23:54,800',
#                'text': 'And I was very touched, because I realized that I look like my father.'}),
#              (223,
#               {'time': '00:23:56,520 --> 00:23:58,160',
#                'text': 'And yes, I recognize that sometimes...'}),
#              (224,
#               {'time': '00:23:59,160 --> 00:24:00,920',
#                'text': 'I can give you a little rage.'}),
#              (225,
#               {'time': '00:24:02,160 --> 00:24:03,520',
#                'text': 'More like a lot of rage.'}),
#              (226,
#               {'time': '00:24:04,720 --> 00:24:05,720', 'text': 'A lot.'}),
#              (227,
#               {'time': '00:24:08,160 --> 00:24:09,239',
#                'text': 'One to zero.'}),
#              (228,
#               {'time': '00:24:10,000 --> 00:24:11,520',
#                'text': 'One to zero from what?'}),
#              (229,
#               {'time': '00:24:11,680 --> 00:24:13,439',
#                'text': "Well, I've explained one thing to you..."}),
#              (230,
#               {'time': '00:24:14,040 --> 00:24:16,040',
#                'text': 'staff that, for me, is not pleasant.'}),
#              (231,
#               {'time': '00:24:17,400 --> 00:24:18,400', 'text': 'And you?'}),
#              (232,
#               {'time': '00:24:19,920 --> 00:24:22,840',
#                'text': 'Do you have any weak points you want to explain to me?'}),
#              (233,
#               {'time': '00:24:40,320 --> 00:24:41,360',
#                'text': 'According to Aristóteles, who had to have the best flutes were the best flute players.'}),
#              (234,
#               {'time': '00:24:41,520 --> 00:24:43,840',
#                'text': 'According to Aristóteles, who had to have the best flutes were the best flute players.'}),
#              (235,
#               {'time': '00:24:44,000 --> 00:24:45,640',
#                'text': 'According to Aristóteles, who had to have the best flutes were the best flute players.'}),
#              (236,
#               {'time': '00:24:45,800 --> 00:24:47,479',
#                'text': 'It was a way to reward them for their musical virtue.'}),
#              (237,
#               {'time': '00:24:47,640 --> 00:24:48,959',
#                'text': 'It was a way to reward them for their musical virtue.'}),
#              (238,
#               {'time': '00:24:49,600 --> 00:24:51,600',
#                'text': 'In politics it would also have to be so, that the most exemplary citizens were those who agreed to the political charges of the most responsibility.'}),
#              (239,
#               {'time': '00:24:51,760 --> 00:24:54,879',
#                'text': 'In politics it would also have to be so, that the most exemplary citizens were those who agreed to the political charges of the most responsibility.'}),
#              (240,
#               {'time': '00:24:55,040 --> 00:24:57,520',
#                'text': 'In politics it would also have to be so, that the most exemplary citizens were those who agreed to the political charges of the most responsibility.'}),
#              (241,
#               {'time': '00:24:57,680 --> 00:24:59,800',
#                'text': 'Plato and Aristótela had it very clear: politics has to be decent because an indecent destroys everything that rules.'}),
#              (242,
#               {'time': '00:24:59,959 --> 00:25:01,680',
#                'text': 'Plato and Aristótela had it very clear: politics has to be decent because an indecent destroys everything that rules.'}),
#              (243,
#               {'time': '00:25:01,840 --> 00:25:05,200',
#                'text': 'Plato and Aristótela had it very clear: politics has to be decent because an indecent destroys everything that rules.'}),
#              (244,
#               {'time': '00:25:05,680 --> 00:25:06,680',
#                'text': 'And you, if in the future you were dedicated to politics, would you be intelligent?'}),
#              (245,
#               {'time': '00:25:07,640 --> 00:25:09,920',
#                'text': 'And you, if in the future you were dedicated to politics, would you be intelligent?'}),
#              (246,
#               {'time': '00:25:10,879 --> 00:25:12,080',
#                'text': 'And you, if in the future you were dedicated to politics, would you be intelligent?'}),
#              (247,
#               {'time': '00:25:13,840 --> 00:25:15,640',
#                'text': "We all know we don't have to steal."}),
#              (248,
#               {'time': '00:25:15,959 --> 00:25:17,520',
#                'text': 'Fuck, what an exemplary class.'}),
#              (249,
#               {'time': '00:25:17,680 --> 00:25:20,879',
#                'text': 'If the boss pays me an extra in black money, I love it.'}),
#              (250,
#               {'time': '00:25:22,080 --> 00:25:22,959',
#                'text': "What's wrong?"}),
#              (251,
#               {'time': '00:25:23,119 --> 00:25:24,959',
#                'text': "Let's see, Silvia, the first day of class you told us that the associate teachers will charge, at most, 500 euros."}),
#              (252,
#               {'time': '00:25:25,119 --> 00:25:27,479',
#                'text': "Let's see, Silvia, the first day of class you told us that the associate teachers will charge, at most, 500 euros."}),
#              (253,
#               {'time': '00:25:27,640 --> 00:25:28,760',
#                'text': "Let's see, Silvia, the first day of class you told us that the associate teachers will charge, at most, 500 euros."}),
#              (254,
#               {'time': '00:25:28,920 --> 00:25:30,439',
#                'text': 'I see you want to cheer me up today.'}),
#              (255,
#               {'time': '00:25:30,600 --> 00:25:33,320',
#                'text': 'Okay, excuse me. Also, university fees are scandalously high and to the many who ask for a scholarship, or we approve everything or they throw us out.'}),
#              (256,
#               {'time': '00:25:33,479 --> 00:25:34,920',
#                'text': 'Okay, excuse me. Also, university fees are scandalously high and to the many who ask for a scholarship, or we approve everything or they throw us out.'}),
#              (257,
#               {'time': '00:25:35,080 --> 00:25:38,080',
#                'text': 'Okay, excuse me. Also, university fees are scandalously high and to the many who ask for a scholarship, or we approve everything or they throw us out.'}),
#              (258,
#               {'time': '00:25:38,239 --> 00:25:40,439',
#                'text': 'Faced with this panorama, who of you would reject an envelope with money? Come on, raise your hand.'}),
#              (259,
#               {'time': '00:25:40,600 --> 00:25:43,600',
#                'text': 'Faced with this panorama, who of you would reject an envelope with money? Come on, raise your hand.'}),
#              (260,
#               {'time': '00:25:48,439 --> 00:25:50,800',
#                'text': 'It is clear that the Treasury should not be let down and that moral principles should be those, but the problem is that people move away from the system because it is very punishing.'}),
#              (261,
#               {'time': '00:25:50,959 --> 00:25:53,600',
#                'text': 'It is clear that the Treasury should not be let down and that moral principles should be those, but the problem is that people move away from the system because it is very punishing.'}),
#              (262,
#               {'time': '00:25:53,760 --> 00:25:56,320',
#                'text': 'It is clear that the Treasury should not be let down and that moral principles should be those, but the problem is that people move away from the system because it is very punishing.'}),
#              (263,
#               {'time': '00:25:56,479 --> 00:25:57,720',
#                'text': 'It is clear that the Treasury should not be let down and that moral principles should be those, but the problem is that people move away from the system because it is very punishing.'}),
#              (264,
#               {'time': '00:25:58,479 --> 00:26:00,320',
#                'text': 'Could you explain it a little more?'}),
#              (265,
#               {'time': '00:26:01,160 --> 00:26:02,160',
#                'text': "Well, I don't know, my father a few years ago..."}),
#              (266,
#               {'time': '00:26:03,080 --> 00:26:05,040',
#                'text': "Well, I don't know, my father a few years ago..."}),
#              (267,
#               {'time': '00:26:05,200 --> 00:26:07,800',
#                'text': "I'm serious, listen to me."}),
#              (268,
#               {'time': '00:26:10,000 --> 00:26:11,600',
#                'text': 'And he, for being punctual and working well, was paid a bonus.'}),
#              (269,
#               {'time': '00:26:11,760 --> 00:26:13,560',
#                'text': 'And he, for being punctual and working well, was paid a bonus.'}),
#              (270,
#               {'time': '00:26:13,720 --> 00:26:15,920',
#                'text': 'So why does the system not reward exemplary citizens?'}),
#              (271,
#               {'time': '00:26:16,080 --> 00:26:17,600',
#                'text': 'So why does the system not reward exemplary citizens?'}),
#              (272,
#               {'time': '00:26:17,760 --> 00:26:19,760',
#                'text': 'Paying taxes is your obligation.'}),
#              (273,
#               {'time': '00:26:19,920 --> 00:26:21,439',
#                'text': 'Okay, but I insist, there are millions of people paying their taxes all their lives and in the end, what do they receive when they retire?'}),
#              (274,
#               {'time': '00:26:21,600 --> 00:26:24,640',
#                'text': 'Okay, but I insist, there are millions of people paying their taxes all their lives and in the end, what do they receive when they retire?'}),
#              (275,
#               {'time': '00:26:24,800 --> 00:26:26,720',
#                'text': 'Okay, but I insist, there are millions of people paying their taxes all their lives and in the end, what do they receive when they retire?'}),
#              (276,
#               {'time': '00:26:26,879 --> 00:26:29,520',
#                'text': "-Pol, you're an anti-system."}),
#              (277,
#               {'time': '00:26:29,680 --> 00:26:31,920',
#                'text': 'Marqués de Casamiquela, I love the system.'}),
#              (278,
#               {'time': '00:26:32,080 --> 00:26:34,479',
#                'text': "The problem is that the system doesn't want me."}),
#              (279,
#               {'time': '00:26:35,800 --> 00:26:36,879',
#                'text': 'Wait a minute, wait a minute.'}),
#              (280,
#               {'time': '00:26:37,040 --> 00:26:38,000',
#                'text': 'Pol, the system has to monitor and punish the corrupt, otherwise everything goes to hell.'}),
#              (281,
#               {'time': '00:26:38,400 --> 00:26:41,280',
#                'text': 'Pol, the system has to monitor and punish the corrupt, otherwise everything goes to hell.'}),
#              (282,
#               {'time': '00:26:41,439 --> 00:26:42,879',
#                'text': 'Pol, the system has to monitor and punish the corrupt, otherwise everything goes to hell.'}),
#              (283,
#               {'time': '00:26:43,439 --> 00:26:45,439',
#                'text': "Let's see, Biel, a little thing, who cares about a parent who only punishes?"}),
#              (284,
#               {'time': '00:26:45,600 --> 00:26:48,840',
#                'text': "Let's see, Biel, a little thing, who cares about a parent who only punishes?"}),
#              (285,
#               {'time': '00:26:49,000 --> 00:26:51,280',
#                'text': "We also like to be pampered a little, don't we?"}),
#              (286,
#               {'time': '00:26:51,439 --> 00:26:54,720',
#                'text': 'And why are our good deeds not rewarded?'}),
#              (287,
#               {'time': '00:26:54,879 --> 00:26:57,560',
#                'text': "I wonder: wouldn't the fraudsters diminish if they rewarded us when we behaved well?"}),
#              (288,
#               {'time': '00:26:57,720 --> 00:27:00,119',
#                'text': "I wonder: wouldn't the fraudsters diminish if they rewarded us when we behaved well?"}),
#              (289,
#               {'time': '00:27:00,280 --> 00:27:01,720',
#                'text': "Wouldn't there be less corrupt?"}),
#              (290,
#               {'time': '00:27:01,879 --> 00:27:03,680',
#                'text': "It's a question I leave in the air."}),
#              (291,
#               {'time': '00:27:03,840 --> 00:27:05,800',
#                'text': "Honestly, if I spend my life paying my taxes religiously, I'd like to receive a letter from the IRS saying..."}),
#              (292,
#               {'time': '00:27:05,959 --> 00:27:07,959',
#                'text': "Honestly, if I spend my life paying my taxes religiously, I'd like to receive a letter from the IRS saying..."}),
#              (293,
#               {'time': '00:27:08,119 --> 00:27:11,000',
#                'text': "Honestly, if I spend my life paying my taxes religiously, I'd like to receive a letter from the IRS saying..."}),
#              (294,
#               {'time': '00:27:26,119 --> 00:27:27,119',
#                'text': 'No, nothing, nothing.'}),
#              (295,
#               {'time': '00:27:41,280 --> 00:27:42,640',
#                'text': 'You want me to come with you?'}),
#              (296,
#               {'time': '00:27:48,520 --> 00:27:49,520',
#                'text': "That's good."}),
#              (297,
#               {'time': '00:27:55,560 --> 00:27:56,560',
#                'text': 'What are you doing?'}),
#              (298,
#               {'time': '00:27:57,119 --> 00:27:58,239', 'text': 'Hangover?'}),
#              (299,
#               {'time': '00:28:02,119 --> 00:28:05,280',
#                'text': 'Listen, yesterday was already... it was bad.'}),
#              (300,
#               {'time': '00:28:06,840 --> 00:28:09,320',
#                'text': "But, well, I won't fool you, I know what I'm doing."}),
#              (301,
#               {'time': '00:28:10,560 --> 00:28:11,879',
#                'text': "It's okay, Oti."}),
#              (302,
#               {'time': '00:28:12,400 --> 00:28:14,200',
#                'text': '- Sure, I like you very much.'}),
#              (303,
#               {'time': '00:28:14,600 --> 00:28:16,720',
#                'text': 'In addition, we all have our desires.'}),
#              (304,
#               {'time': '00:28:19,160 --> 00:28:21,280',
#                'text': 'I want us to be friends.'}),
#              (305,
#               {'time': '00:28:22,200 --> 00:28:23,119',
#                'text': 'In the end what?'}),
#              (306,
#               {'time': '00:28:23,280 --> 00:28:25,360',
#                'text': 'Do we have the ass we deserve or not?'}),
#              (307,
#               {'time': '00:28:26,680 --> 00:28:28,640',
#                'text': "Hey, we're here to pay for the card."}),
#              (308,
#               {'time': '00:28:37,840 --> 00:28:40,600',
#                'text': 'Oh, girl, is that, on Mandri Street, what did you expect?'}),
#              (309,
#               {'time': '00:28:40,760 --> 00:28:42,560',
#                'text': 'Go to Ronda Mitre, by the way.'}),
#              (310,
#               {'time': '00:28:42,879 --> 00:28:45,280',
#                'text': "- Not so much laugh, Ester, I'm not stupid."}),
#              (311,
#               {'time': '00:28:45,439 --> 00:28:46,640',
#                'text': "Susana, don't be angry."}),
#              (312,
#               {'time': '00:28:46,800 --> 00:28:49,760',
#                'text': 'How about the exhibition? Are you going to buy something?'}),
#              (313,
#               {'time': '00:28:51,959 --> 00:28:55,280',
#                'text': 'Oh, buy a painting, your walls are so boring.'}),
#              (314,
#               {'time': '00:28:55,439 --> 00:28:57,840',
#                'text': 'Sure, buy pictures, instead of stealing them.'}),
#              (315,
#               {'time': '00:29:00,239 --> 00:29:01,600',
#                'text': "Don't start, do me a favor."}),
#              (316,
#               {'time': '00:29:01,760 --> 00:29:04,000',
#                'text': 'If you come to say nonsense, you better get out.'}),
#              (317,
#               {'time': '00:29:04,160 --> 00:29:06,520',
#                'text': "Mom, I told you he'd come."}),
#              (318,
#               {'time': '00:29:07,160 --> 00:29:08,800',
#                'text': 'Fuck, Ester, what about this coat?'}),
#              (319,
#               {'time': '00:29:09,400 --> 00:29:10,520',
#                'text': 'Do you like it?'}),
#              (320,
#               {'time': '00:29:12,879 --> 00:29:15,680',
#                'text': 'Minerva Picotti, my mother, my aunt Ester and her friends.'}),
#              (321,
#               {'time': '00:29:17,040 --> 00:29:18,640',
#                'text': 'Minerva Picotti, my mother, my aunt Ester and her friends.'}),
#              (322,
#               {'time': '00:29:19,680 --> 00:29:21,320',
#                'text': 'What was your name again?'}),
#              (323,
#               {'time': '00:29:21,479 --> 00:29:22,439',
#                'text': 'Rai, how ugly!'}),
#              (324,
#               {'time': '00:29:29,760 --> 00:29:30,760',
#                'text': "That's nice!"}),
#              (325,
#               {'time': '00:29:33,680 --> 00:29:34,959',
#                'text': 'Esther, please!'}),
#              (326,
#               {'time': '00:29:35,560 --> 00:29:36,920',
#                'text': "Well, we're over here."}),
#              (327,
#               {'time': '00:29:40,360 --> 00:29:41,959',
#                'text': "In Argentina they're terrible, aren't they?"}),
#              (328,
#               {'time': '00:29:42,119 --> 00:29:45,040',
#                'text': "- Shut up, he'll hear you."}),
#              (329,
#               {'time': '00:29:57,520 --> 00:29:59,160',
#                'text': "My mother doesn't know me."}),
#              (330,
#               {'time': '00:29:59,760 --> 00:30:02,600',
#                'text': 'When I was little, I never gave myself what I wanted.'}),
#              (331,
#               {'time': '00:30:03,040 --> 00:30:06,800',
#                'text': 'If I asked for a toy car, she sent someone to buy me a big motor car, you know?'}),
#              (332,
#               {'time': '00:30:06,959 --> 00:30:09,400',
#                'text': 'If I asked for a toy car, she sent someone to buy me a big motor car, you know?'}),
#              (333,
#               {'time': '00:30:27,959 --> 00:30:30,160',
#                'text': 'Sometimes I miss reading a book.'}),
#              (334,
#               {'time': '00:30:34,400 --> 00:30:36,840',
#                'text': 'In the "insti" I read "The story of a castaway".'}),
#              (335,
#               {'time': '00:30:37,360 --> 00:30:39,280',
#                'text': "It's short, but it's okay, huh?"}),
#              (336,
#               {'time': '00:30:43,119 --> 00:30:44,239',
#                'text': 'Today, in class, the Weierstrass theorem was explained to us.'}),
#              (337,
#               {'time': '00:30:44,400 --> 00:30:46,760',
#                'text': 'Today, in class, the Weierstrass theorem was explained to us.'}),
#              (338, {'time': '00:30:52,520 --> 00:30:53,520', 'text': 'Here?'}),
#              (339,
#               {'time': '00:30:59,560 --> 00:31:00,560',
#                'text': 'According to the theorem, if a function ephe...'}),
#              (340,
#               {'time': '00:31:01,280 --> 00:31:03,680',
#                'text': 'According to the theorem, if a function ephe...'}),
#              (341,
#               {'time': '00:31:03,840 --> 00:31:04,959',
#                'text': 'Of equis...'}),
#              (342,
#               {'time': '00:31:05,840 --> 00:31:08,280',
#                'text': "It's continuous in an interval..."}),
#              (343,
#               {'time': '00:31:08,760 --> 00:31:10,600',
#                'text': 'a, b, then, efe...'}),
#              (344,
#               {'time': '00:31:12,040 --> 00:31:14,040',
#                'text': 'a, b, then, efe...'}),
#              (345,
#               {'time': '00:31:14,879 --> 00:31:15,879',
#                'text': "It's narrowed down in this interval."}),
#              (346,
#               {'time': '00:31:16,400 --> 00:31:17,760',
#                'text': "It's narrowed down in this interval."}),
#              (347,
#               {'time': '00:31:18,800 --> 00:31:21,640',
#                'text': '"Filled down" means that it is limited by two numbers: above...'}),
#              (348,
#               {'time': '00:31:21,800 --> 00:31:22,800',
#                'text': '"Filled down" means that it is limited by two numbers: above...'}),
#              (349,
#               {'time': '00:31:25,600 --> 00:31:26,720',
#                'text': 'And down there.'}),
#              (350,
#               {'time': '00:31:38,239 --> 00:31:40,760',
#                'text': "That I don't want to be sold, I want it for myself."}),
#              (351,
#               {'time': '00:31:48,160 --> 00:31:49,920',
#                'text': "What's wrong with you?"}),
#              (352,
#               {'time': '00:32:13,760 --> 00:32:15,840',
#                'text': "Okay, no, Minerva, I didn't mean that."}),
#              (353,
#               {'time': '00:32:34,360 --> 00:32:36,479',
#                'text': "I've been offered a job in a high school."}),
#              (354,
#               {'time': '00:32:37,080 --> 00:32:38,200',
#                'text': 'The next course.'}),
#              (355,
#               {'time': '00:32:41,400 --> 00:32:42,560',
#                'text': "He'd charge twice as much."}),
#              (356,
#               {'time': '00:32:48,479 --> 00:32:49,879',
#                'text': "I'm not so clear."}),
#              (357,
#               {'time': '00:32:50,760 --> 00:32:54,000',
#                'text': "I don't know, the truth is I feel good here, I feel motivated."}),
#              (358,
#               {'time': '00:32:54,560 --> 00:32:57,920',
#                'text': "And more now, that first-timers are better than last year's."}),
#              (359,
#               {'time': '00:32:59,040 --> 00:33:00,959',
#                'text': 'And so much! Today in class a superchulo debate has been organized, they have not stopped intervening.'}),
#              (360,
#               {'time': '00:33:01,119 --> 00:33:02,320',
#                'text': 'And so much! Today in class a superchulo debate has been organized, they have not stopped intervening.'}),
#              (361,
#               {'time': '00:33:02,479 --> 00:33:03,920',
#                'text': 'And so much! Today in class a superchulo debate has been organized, they have not stopped intervening.'}),
#              (362,
#               {'time': '00:33:08,840 --> 00:33:10,040',
#                'text': "I'm not kidding."}),
#              (363,
#               {'time': '00:33:11,040 --> 00:33:12,879',
#                'text': 'I have a feeling they like me.'}),
#              (364,
#               {'time': '00:33:13,760 --> 00:33:15,160',
#                'text': "That's why I hesitate to leave."}),
#              (365,
#               {'time': '00:33:16,080 --> 00:33:17,400',
#                'text': 'Here I have students...'}),
#              (366,
#               {'time': '00:33:18,080 --> 00:33:19,720',
#                'text': 'especially interesting.'}),
#              (367,
#               {'time': '00:33:42,360 --> 00:33:43,720',
#                'text': "It's cool in the fall, isn't it?"}),
#              (368,
#               {'time': '00:33:46,200 --> 00:33:47,479',
#                'text': "It's dark before."}),
#              (369,
#               {'time': '00:33:49,720 --> 00:33:51,760',
#                'text': 'Okay. Was that it?'}),
#              (370,
#               {'time': '00:33:51,920 --> 00:33:54,800',
#                'text': 'Shall we take a break? I have a croissant.'}),
#              (371,
#               {'time': '00:33:56,200 --> 00:33:58,119',
#                'text': 'If you give me half.'}),
#              (372,
#               {'time': '00:34:01,160 --> 00:34:02,239', 'text': 'Leave it.'}),
#              (373,
#               {'time': '00:34:02,400 --> 00:34:04,600',
#                'text': "No, well, yeah, I'll let you bite it."}),
#              (374,
#               {'time': '00:34:06,000 --> 00:34:07,479',
#                'text': "You're funny enough, man, huh?"}),
#              (375,
#               {'time': '00:34:08,080 --> 00:34:10,040',
#                'text': "Why? I look smaller, don't I?"}),
#              (376,
#               {'time': '00:34:18,439 --> 00:34:19,959',
#                'text': 'Have you fallen in love or what?'}),
#              (377,
#               {'time': '00:34:20,119 --> 00:34:21,080',
#                'text': 'Hey, hey, hey, hey, hey, hey, hey!'}),
#              (378,
#               {'time': '00:34:21,920 --> 00:34:23,640',
#                'text': "You can't fall in love so fast."}),
#              (379,
#               {'time': '00:34:37,840 --> 00:34:39,320',
#                'text': "I'm in love with Minerva."}),
#              (380,
#               {'time': '00:34:40,280 --> 00:34:43,000',
#                'text': 'But she prefers art rather than croissants.'}),
#              (381,
#               {'time': '00:34:45,640 --> 00:34:46,800',
#                'text': 'Did you say something?'}),
#              (382,
#               {'time': '00:38:26,439 --> 00:38:28,239',
#                'text': "How's it going?"}),
#              (383,
#               {'time': '00:38:29,600 --> 00:38:30,600',
#                'text': 'You were right.'}),
#              (384,
#               {'time': '00:38:32,479 --> 00:38:34,600',
#                'text': "What the ball did to me the other day in class didn't bother me at all."}),
#              (385,
#               {'time': '00:38:34,760 --> 00:38:35,760',
#                'text': "What the ball did to me the other day in class didn't bother me at all."}),
#              (386,
#               {'time': '00:38:38,320 --> 00:38:39,640',
#                'text': 'I felt humiliated.'}),
#              (387,
#               {'time': '00:38:44,640 --> 00:38:46,040',
#                'text': 'I recognize that...'}),
#              (388,
#               {'time': '00:38:48,239 --> 00:38:49,560',
#                'text': "I don't like to lose."}),
#              (389,
#               {'time': '00:38:52,680 --> 00:38:56,040',
#                'text': "And what pisses me off is that I'm known to be lost."}),
#              (390,
#               {'time': '00:39:03,305 --> 00:40:03,517',
#                'text': 'Please rate this subtitle at www.osdb.link/6y8jb Help others choose the best'})])

# %%
'''
PART 5: write translated data into .srt
'''

newf = fname.replace('.srt', '-spa.srt')
with open(newf, 'w', encoding='utf8') as writef:
    for key, vals in transdata.items():
        writef.write(str(key) + '\n')
        writef.write(vals['time'] + '\n')
        writef.write(vals['text'] + '\n')
        writef.write('\n')
